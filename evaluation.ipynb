# %%
#Dependencies
import pandas as pd
import numpy as np
import tensorflow as tf
import itertools
import matplotlib.pyplot as plt
import time

from envs import OfflineEnv
from recommender import DRRAgent

import os

ROOT_DIR = os.getcwd()
DATA_DIR = os.path.join(ROOT_DIR, 'ml-1m/')
STATE_SIZE = 10

# %%
def evaluate(recommender, env, top_k=False):

        recommender.load_model('/home/diominor/Workspace/DRR/save_weights/actor_50000.h5', '/home/diominor/Workspace/DRR/save_weights/critic_50000.h5')

        # episodic reward 리셋
        episode_reward = 0
        correct_count = 0
        steps = 0
        # Environment 리셋
        user_id, items_ids, done = env.reset()
        print(f'user_id : {user_id}, rated_items_length:{len(env.user_items)}')
        print('items : \n', np.array(env.get_items_names(items_ids)))
        
        while not done:
            
            # Observe current state & Find action
            ## Embedding 해주기
            user_id = tf.convert_to_tensor(user_id)
            items_ids = tf.convert_to_tensor(items_ids)
            user_eb, items_eb = recommender.actor.embedding_network(user_id, items_ids)
            user_eb = tf.reshape(user_eb, (1,1, *user_eb.shape))
            items_eb = tf.reshape(items_eb, (1,*items_eb.shape))
            ## Action(ranking score) 출력
            action, _ = recommender.actor.network(user_eb, items_eb)
            ## Item 추천
            recommended_item = recommender.actor.recommend_item(action, env.recommended_items, top_k=top_k, is_test=True)
            print(f'recommended items ids : {recommended_item}')
            print(f'recommened items : \n {np.array(env.get_items_names(recommended_item), dtype=object)}')
            # Calculate reward & observe new state (in env)
            ## Step
            next_items_ids, reward, done, _ = env.step(recommended_item, top_k=top_k)
            items_ids = next_items_ids
            episode_reward += reward
            steps += 1
            if reward > 0:
                correct_count += 1
                print('GOT IT!!!!')
            print()  

        print(f'precision : {correct_count/steps}, episode_reward : {episode_reward}')
        print()

# %%
#Loading datasets
ratings_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'ratings.dat'), 'r').readlines()]
users_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'users.dat'), 'r').readlines()]
movies_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'movies.dat'),encoding='latin-1').readlines()]
ratings_df = pd.DataFrame(ratings_list, columns = ['UserID', 'MovieID', 'Rating', 'Timestamp'], dtype = np.uint32)
movies_df = pd.DataFrame(movies_list, columns = ['MovieID', 'Title', 'Genres'])
movies_df['MovieID'] = movies_df['MovieID'].apply(pd.to_numeric)

# %%
# 영화 id를 영화 제목으로
movies_id_to_movies = {movie[0]: movie[1:] for movie in movies_list}

# %%
len(movies_list)
# Out:
# 3883

# %%
ratings_df.head(5)
# Out:
#   UserID MovieID Rating  Timestamp
# 0      1    1193      5  978300760
# 1      1     661      3  978302109
# 2      1     914      3  978301968
# 3      1    3408      4  978300275
# 4      1    2355      5  978824291

# %%
# # 사용자가 선택한 영화 분포 확인
# plt.figure(figsize=(20,10))
# plt.hist(ratings_df["MovieID"], bins=3883)
# plt.show()

# %%
# 결측치 확인
ratings_df.isnull().sum()
# Out:
# UserID       0
# MovieID      0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
# 최대값 확인
print(len(set(ratings_df["UserID"])) == max([int(i) for i in set(ratings_df["UserID"])]))
print(max([int(i) for i in set(ratings_df["UserID"])]))
# Out:
# True
# 6040

# %%
ratings_df = ratings_df.applymap(int)

# %%
# 유저별로 본 영화들 순서대로 정리
users_dict = {user : [] for user in set(ratings_df["UserID"])}
users_dict[1]
# Out:
# []

# %%
# 시간 순으로 정렬하기
ratings_df = ratings_df.sort_values(by='Timestamp', ascending=True)
ratings_df.head(5)
# Out:
#          UserID  MovieID  Rating  Timestamp
# 1000138    6040      858       4  956703932
# 1000153    6040     2384       4  956703954
# 999873     6040      593       5  956703954
# 1000007    6040     1961       4  956703977
# 1000192    6040     2019       5  956703977

# %%
# 유저 딕셔너리에 (영화, 평점)쌍 넣기
ratings_df_gen = ratings_df.iterrows()
for data in ratings_df_gen:
    users_dict[data[1]['UserID']].append((data[1]['MovieID'], data[1]['Rating']))
users_dict[1]
# Out:
# [(3186, 4),
#  (1721, 4),
#  (1270, 5),
#  (1022, 5),
#  (2340, 3),
#  (1836, 5),
#  (3408, 4),
#  (1207, 4),
#  (2804, 5),
#  (260, 4),
#  (720, 3),
#  (1193, 5),
#  (919, 4),
#  (608, 4),
#  (2692, 4),
#  (1961, 5),
#  (2028, 5),
#  (3105, 5),
#  (938, 4),
#  (1035, 5),
#  (1962, 4),
#  (1028, 5),
#  (2018, 4),
#  (150, 5),
#  (1097, 4),
#  (914, 3),
#  (1287, 5),
#  (2797, 4),
#  (1246, 4),
#  (2762, 4),
#  (661, 3),
#  (2918, 4),
#  (531, 4),
#  (3114, 4),
#  (2791, 4),
#  (1029, 5),
#  (2321, 3),
#  (1197, 3),
#  (594, 4),
#  (2398, 4),
#  (1545, 4),
#  (527, 5),
#  (745, 3),
#  (595, 5),
#  (588, 4),
#  (1, 5),
#  (2687, 3),
#  (783, 4),
#  (2294, 4),
#  (2355, 5),
#  (1907, 4),
#  (1566, 4),
#  (48, 5)]

# %%
# 각 유저별 영화 히스토리 길이
users_history_lens = [len(users_dict[u]) for u in set(ratings_df["UserID"])]
users_history_lens[:10]
# Out:
# [53, 129, 51, 21, 198, 71, 31, 139, 106, 401]

# %%
users_dict[1]
# Out:
# [(3186, 4),
#  (1721, 4),
#  (1270, 5),
#  (1022, 5),
#  (2340, 3),
#  (1836, 5),
#  (3408, 4),
#  (1207, 4),
#  (2804, 5),
#  (260, 4),
#  (720, 3),
#  (1193, 5),
#  (919, 4),
#  (608, 4),
#  (2692, 4),
#  (1961, 5),
#  (2028, 5),
#  (3105, 5),
#  (938, 4),
#  (1035, 5),
#  (1962, 4),
#  (1028, 5),
#  (2018, 4),
#  (150, 5),
#  (1097, 4),
#  (914, 3),
#  (1287, 5),
#  (2797, 4),
#  (1246, 4),
#  (2762, 4),
#  (661, 3),
#  (2918, 4),
#  (531, 4),
#  (3114, 4),
#  (2791, 4),
#  (1029, 5),
#  (2321, 3),
#  (1197, 3),
#  (594, 4),
#  (2398, 4),
#  (1545, 4),
#  (527, 5),
#  (745, 3),
#  (595, 5),
#  (588, 4),
#  (1, 5),
#  (2687, 3),
#  (783, 4),
#  (2294, 4),
#  (2355, 5),
#  (1907, 4),
#  (1566, 4),
#  (48, 5)]

# %%
users_num = max(ratings_df["UserID"])+1
items_num = max(ratings_df["MovieID"])+1

# %%
print(users_num, items_num)
# Out:
# 6041 3953

# %% [markdown]
# ### Training setting

# %%
train_users_num = int(users_num * 0.8)
train_items_num = items_num
print(train_users_num, train_items_num)
# Out:
# 4832 3953

# %%
train_users_dict = {k:users_dict[k] for k in range(1, train_users_num+1)}
train_users_history_lens = users_history_lens[:train_users_num]
print(len(train_users_dict),len(train_users_history_lens))
# Out:
# 4832 4832

# %% [markdown]
# ### Evaluating setting

# %%
eval_users_num = int(users_num * 0.2)
eval_items_num = items_num
print(eval_users_num, eval_items_num)
# Out:
# 1208 3953

# %%
eval_users_dict = {k:users_dict[k] for k in range(users_num-eval_users_num, users_num)}
eval_users_history_lens = users_history_lens[-eval_users_num:]
print(len(eval_users_dict),len(eval_users_history_lens))
# Out:
# 1208 1208

# %% [markdown]
# ### 준비된것
# users_dict, users_history_len, movies_id_to_movies, sers_num, items_num

# %% [markdown]
# ### Evalutation

# %%
tf.keras.backend.set_floatx('float64')

# %%
env = OfflineEnv(eval_users_dict, eval_users_history_lens, movies_id_to_movies, STATE_SIZE)
recommender = DRRAgent(env, users_num, items_num, STATE_SIZE)
recommender.actor.build_networks()
recommender.critic.build_networks()
evaluate(recommender, env, top_k=5)
# Out:
# user_id : 5763, rated_items_length:677
# items :
#  [['Cocoon (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode V - The Empire Strikes Back (1980)'
#   'Action|Adventure|Drama|Sci-Fi|War']
#  ['Honeymoon in Vegas (1992)' 'Comedy|Romance']
#  ['Peggy Sue Got Married (1986)' 'Comedy|Romance']
#  ['Silence of the Lambs, The (1991)' 'Drama|Thriller']
#  ['Braveheart (1995)' 'Action|Drama|War']
#  ['L.A. Confidential (1997)' 'Crime|Film-Noir|Mystery|Thriller']
#  ['Maltese Falcon, The (1941)' 'Film-Noir|Mystery']
#  ['Manchurian Candidate, The (1962)' 'Film-Noir|Thriller']
#  ['Chinatown (1974)' 'Film-Noir|Mystery|Thriller']]
# recommended items ids : [ 823 2574  406 1254 3630]
# recommened items :
#  [['Collectionneuse, La (1967)' 'Drama']
#  ['Out-of-Towners, The (1999)' 'Comedy']
#  ['Federal Hill (1994)' 'Drama']
#  ['Treasure of the Sierra Madre, The (1948)' 'Adventure']
#  ["House of Exorcism, The (La Casa dell'esorcismo) (1974)" 'Horror']]
# GOT IT!!!!
#
# recommended items ids : [1879 2332 3757  633 1172]
# recommened items :
#  [['Hanging Garden, The (1997)' 'Drama']
#  ['Belly (1998)' 'Crime|Drama']
#  ['Asylum (1972)' 'Horror']
#  ['Denise Calls Up (1995)' 'Comedy']
#  ['Cinema Paradiso (1988)' 'Comedy|Drama|Romance']]
# GOT IT!!!!
#
# recommended items ids : [2118 1499 3612 1753 1107]
# recommened items :
#  [['Dead Zone, The (1983)' 'Horror|Thriller']
#  ['Anaconda (1997)' 'Action|Adventure|Thriller']
#  ['Slipper and the Rose, The (1976)' 'Adventure|Musical|Romance']
#  ['Half Baked (1998)' 'Comedy']
#  ['Loser (1991)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [  51 2435  836 1331  866]
# recommened items :
#  [['Guardian Angel (1994)' 'Action|Drama|Thriller']
#  ['Hurlyburly (1998)' 'Drama']
#  ['Chain Reaction (1996)' 'Action|Adventure|Thriller']
#  ['Audrey Rose (1977)' 'Horror']
#  ['Bound (1996)' 'Crime|Drama|Romance|Thriller']]
#
# recommended items ids : [3745 3783 1312 2061 3323]
# recommened items :
#  [['Titan A.E. (2000)' 'Adventure|Animation|Sci-Fi']
#  ['Croupier (1998)' 'Crime|Drama']
#  ['Female Perversions (1996)' 'Drama']
#  ['Full Tilt Boogie (1997)' 'Documentary']
#  ['Chain of Fools (2000)' 'Comedy|Crime']]
#
# recommended items ids : [3741  418 1677  375 2171]
# recommened items :
#  [['Badlands (1973)' 'Crime|Drama']
#  ['Being Human (1993)' 'Drama']
#  ['Critical Care (1997)' 'Comedy']
#  ['Safe Passage (1994)' 'Drama']
#  ['Next Stop, Wonderland (1998)' 'Comedy|Drama|Romance']]
#
# recommended items ids : [3361 3282 3232 3146 3173]
# recommened items :
#  [['Bull Durham (1988)' 'Comedy']
#  ['Different for Girls (1996)' 'Comedy']
#  ['Seven Chances (1925)' 'Comedy']
#  ['Deuce Bigalow: Male Gigolo (1999)' 'Comedy']
#  ['Any Given Sunday (1999)' 'Drama']]
#
# recommended items ids : [ 221 1635 2646 1245 2040]
# recommened items :
#  [list(['Not in list']) list(['Ice Storm, The (1997)', 'Drama'])
#  list(['House of Dracula (1945)', 'Horror'])
#  list(["Miller's Crossing (1990)", 'Drama'])
#  list(['Computer Wore Tennis Shoes, The (1970)', "Children's|Comedy"])]
# GOT IT!!!!
#
# recommended items ids : [ 728 1526 2773 3864 2377]
# recommened items :
#  [['Cold Comfort Farm (1995)' 'Comedy']
#  ["Fathers' Day (1997)" 'Comedy']
#  ['Alice and Martin (Alice et Martin) (1998)' 'Drama']
#  ['Godzilla 2000 (Gojira ni-sen mireniamu) (1999)'
#   'Action|Adventure|Sci-Fi']
#  ['Lifeforce (1985)' 'Horror|Sci-Fi']]
# GOT IT!!!!
#
# recommended items ids : [3093  810  945 1265 1556]
# recommened items :
#  [['McCabe & Mrs. Miller (1971)' 'Drama|Western']
#  ['Kazaam (1996)' "Children's|Comedy|Fantasy"]
#  ['Top Hat (1935)' 'Comedy|Musical|Romance']
#  ['Groundhog Day (1993)' 'Comedy|Romance']
#  ['Speed 2: Cruise Control (1997)' 'Action|Romance|Thriller']]
# GOT IT!!!!
#
# recommended items ids : [1269 1444 2181 3442 1447]
# recommened items :
#  [['Arsenic and Old Lace (1944)' 'Comedy|Mystery|Thriller']
#  ['Guantanamera (1994)' 'Comedy']
#  ['Marnie (1964)' 'Thriller']
#  ['Band of the Hand (1986)' 'Action']
#  ["Gridlock'd (1997)" 'Crime']]
#
# recommended items ids : [2352 1654 2871 2183 3632]
# recommened items :
#  [['Big Chill, The (1983)' 'Comedy|Drama']
#  ['FairyTale: A True Story (1997)' "Children's|Drama|Fantasy"]
#  ['Deliverance (1972)' 'Adventure|Thriller']
#  ['Man Who Knew Too Much, The (1956)' 'Thriller']
#  ['Monsieur Verdoux (1947)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [1585 1834  144 3383 1421]
# recommened items :
#  [['Love Serenade (1996)' 'Comedy']
#  ['Spanish Prisoner, The (1997)' 'Drama|Thriller']
#  ['Brothers McMullen, The (1995)' 'Comedy']
#  ['Big Fella (1937)' 'Drama|Musical']
#  ['Grateful Dead (1995)' 'Documentary']]
#
# recommended items ids : [ 501 1388 3846 2493 1562]
# recommened items :
#  [['Naked (1993)' 'Drama']
#  ['Jaws 2 (1978)' 'Action|Horror']
#  ['Easy Money (1983)' 'Comedy']
#  ['Harmonists, The (1997)' 'Drama']
#  ['Batman & Robin (1997)' 'Action|Adventure|Crime']]
#
# recommended items ids : [1394  376 1557 1120  178]
# recommened items :
#  [['Raising Arizona (1987)' 'Comedy']
#  ['River Wild, The (1994)' 'Action|Thriller']
#  ['Squeeze (1996)' 'Drama']
#  ['People vs. Larry Flynt, The (1996)' 'Drama']
#  ['Love & Human Remains (1993)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [2571  964  607 3006 2956]
# recommened items :
#  [['Matrix, The (1999)' 'Action|Sci-Fi|Thriller']
#  ['Angel and the Badman (1947)' 'Western']
#  ['Century (1993)' 'Drama']
#  ['Insider, The (1999)' 'Drama']
#  ['Someone to Watch Over Me (1987)' 'Action|Crime|Thriller']]
# GOT IT!!!!
#
# recommended items ids : [3269 3046  647 2239 2846]
# recommened items :
#  [['Forever Young (1992)' 'Adventure|Romance|Sci-Fi']
#  ['Incredibly True Adventure of Two Girls in Love, The (1995)'
#   'Comedy|Romance']
#  ['Courage Under Fire (1996)' 'Drama|War']
#  ["Swept Away (Travolti da un insolito destino nell'azzurro mare d'Agosto) (1975)"
#   'Comedy|Drama']
#  ['Adventures of Milo and Otis, The (1986)' "Children's"]]
#
# recommended items ids : [2416 2450 1173 1885 1584]
# recommened items :
#  [['Back to School (1986)' 'Comedy']
#  ['Howard the Duck (1986)' "Adventure|Children's|Sci-Fi"]
#  ['Cook the Thief His Wife & Her Lover, The (1989)' 'Drama']
#  ['Opposite of Sex, The (1998)' 'Comedy|Drama']
#  ['Contact (1997)' 'Drama|Sci-Fi']]
# GOT IT!!!!
#
# recommended items ids : [ 594 3728  975  268 3217]
# recommened items :
#  [['Snow White and the Seven Dwarfs (1937)' "Animation|Children's|Musical"]
#  ['One False Move (1991)' 'Thriller']
#  ['Something to Sing About (1937)' 'Comedy|Musical']
#  ['Little Odessa (1994)' 'Drama']
#  ['Star Is Born, A (1937)' 'Drama']]
#
# recommended items ids : [3942 1051 2021 3031 3816]
# recommened items :
#  [['Sorority House Massacre II (1990)' 'Horror']
#  ['Trees Lounge (1996)' 'Drama']
#  ['Dune (1984)' 'Fantasy|Sci-Fi']
#  ['Repossessed (1990)' 'Comedy']
#  ['Official Story, The (La Historia Oficial) (1985)' 'Drama']]
#
# recommended items ids : [1758 2466  922 3330  207]
# recommened items :
#  [['Dangerous Beauty (1998)' 'Drama']
#  ['Belizaire the Cajun (1986)' 'Drama']
#  ['Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)' 'Film-Noir']
#  ['Splendor in the Grass (1961)' 'Drama']
#  ['Walk in the Clouds, A (1995)' 'Drama|Romance']]
# GOT IT!!!!
#
# recommended items ids : [2757 3929 1455 1190  484]
# recommened items :
#  [['Frances (1982)' 'Drama']
#  ['Bank Dick, The (1940)' 'Comedy']
#  ['Hotel de Love (1996)' 'Comedy|Romance']
#  ['Tie Me Up! Tie Me Down! (1990)' 'Drama']
#  ['Lassie (1994)' "Adventure|Children's"]]
#
# recommended items ids : [3098 2234 3589 2848  695]
# recommened items :
#  [['Natural, The (1984)' 'Drama']
#  ["Let's Talk About Sex (1998)" 'Drama']
#  ['Kill, Baby... Kill! (Operazione Paura) (1966)' 'Horror']
#  ['Othello (1952)' 'Drama']
#  ['True Crime (1995)' 'Mystery|Thriller']]
#
# recommended items ids : [2763 1152 3446 1013 3162]
# recommened items :
#  [['Thomas Crown Affair, The (1999)' 'Action|Thriller']
#  ['He Walked by Night (1948)' 'Crime|Film-Noir|Thriller']
#  ['Funny Bones (1995)' 'Comedy']
#  ['Parent Trap, The (1961)' "Children's|Drama"]
#  ['Simpatico (1999)' 'Comedy|Drama']]
#
# recommended items ids : [ 368  798  933 3417 2127]
# recommened items :
#  [['Maverick (1994)' 'Action|Comedy|Western']
#  ['Daylight (1996)' 'Action|Adventure|Thriller']
#  ['To Catch a Thief (1955)' 'Comedy|Romance|Thriller']
#  ['Crimson Pirate, The (1952)' 'Adventure|Comedy|Sci-Fi']
#  ['First Love, Last Rites (1997)' 'Drama|Romance']]
#
# recommended items ids : [3338 1600  684 1873  468]
# recommened items :
#  [['For All Mankind (1989)' 'Documentary']
#  ["She's So Lovely (1997)" 'Drama|Romance']
#  ['Windows (1980)' 'Drama']
#  ['Misérables, Les (1998)' 'Drama']
#  ['Englishman Who Went Up a Hill, But Came Down a Mountain, The (1995)'
#   'Comedy|Romance']]
#
# recommended items ids : [3371 1930 2932  683 2952]
# recommened items :
#  [['Bound for Glory (1976)' 'Drama']
#  ['Cavalcade (1933)' 'Drama']
#  ['Days of Heaven (1978)' 'Drama']
#  ["Eye of Vichy, The (Oeil de Vichy, L') (1993)" 'Documentary']
#  ['Hard 8 (a.k.a. Sydney, a.k.a. Hard Eight) (1996)' 'Crime|Thriller']]
#
# recommended items ids : [1478 3860 1148 2015 3582]
# recommened items :
#  [list(['Not in list']) list(['Opportunists, The (1999)', 'Crime'])
#  list(['Wrong Trousers, The (1993)', 'Animation|Comedy'])
#  list(['Absent Minded Professor, The (1961)', "Children's|Comedy|Fantasy"])
#  list(['Jails, Hospitals & Hip-Hop (2000)', 'Drama'])]
# GOT IT!!!!
#
# recommended items ids : [1174 1192  361 3740 2404]
# recommened items :
#  [['Grosse Fatigue (1994)' 'Comedy']
#  ['Paris Is Burning (1990)' 'Documentary']
#  ['It Could Happen to You (1994)' 'Drama|Romance']
#  ['Big Trouble in Little China (1986)' 'Action|Comedy']
#  ['Rambo III (1988)' 'Action|War']]
#
# recommended items ids : [ 414 1530 3025 1256  241]
# recommened items :
#  [list(['Air Up There, The (1994)', 'Comedy']) list(['Not in list'])
#  list(['Rough Night in Jericho (1967)', 'Western'])
#  list(['Duck Soup (1933)', 'Comedy|War'])
#  list(['Fluke (1995)', "Children's|Drama"])]
# GOT IT!!!!
#
# recommended items ids : [  23 1989 2953 1724 3947]
# recommened items :
#  [['Assassins (1995)' 'Thriller']
#  ['Prom Night III: The Last Kiss (1989)' 'Horror']
#  ['Home Alone 2: Lost in New York (1992)' "Children's|Comedy"]
#  ['Full Speed (1996)' 'Drama']
#  ['Get Carter (1971)' 'Thriller']]
#
# recommended items ids : [3471 3407 2283 1378 1070]
# recommened items :
#  [['Close Encounters of the Third Kind (1977)' 'Drama|Sci-Fi']
#  ['Carriers Are Waiting, The (Les Convoyeurs Attendent) (1999)'
#   'Comedy|Drama']
#  ['Sheltering Sky, The (1990)' 'Drama']
#  ['Young Guns (1988)' 'Action|Comedy|Western']
#  ['Macao (1952)' 'Adventure']]
#
# recommended items ids : [ 423  628  993  632 1583]
# recommened items :
#  [['Blown Away (1994)' 'Action|Thriller']
#  ['Primal Fear (1996)' 'Drama|Thriller']
#  ['Infinity (1996)' 'Drama']
#  ['Land and Freedom (Tierra y libertad) (1995)' 'War']
#  ['Simple Wish, A (1997)' "Children's|Fantasy"]]
#
# recommended items ids : [3071 1857 2795 3937 3186]
# recommened items :
#  [['Stand and Deliver (1987)' 'Drama']
#  ['Real Blonde, The (1997)' 'Comedy']
#  ['Vacation (1983)' 'Comedy']
#  ['Runaway (1984)' 'Sci-Fi|Thriller']
#  ['Girl, Interrupted (1999)' 'Drama']]
#
# recommended items ids : [2947 2415 3543 3448  817]
# recommened items :
#  [list(['Goldfinger (1964)', 'Action'])
#  list(['Violets Are Blue... (1986)', 'Drama|Romance'])
#  list(['Diner (1982)', 'Comedy|Drama'])
#  list(['Good Morning, Vietnam (1987)', 'Comedy|Drama|War'])
#  list(['Not in list'])]
# GOT IT!!!!
#
# recommended items ids : [ 784 3414 3625 3130 2041]
# recommened items :
#  [['Cable Guy, The (1996)' 'Comedy']
#  ['Love Is a Many-Splendored Thing (1955)' 'Romance']
#  ['Better Living Through Circuitry (1999)' 'Documentary']
#  ['Bonfire of the Vanities (1990)' 'Comedy']
#  ['Condorman (1981)' "Action|Adventure|Children's|Comedy"]]
#
# recommended items ids : [3355 2036 3066  984  780]
# recommened items :
#  [['Ninth Gate, The (2000)' 'Thriller']
#  ['Blank Check (1994)' "Children's|Comedy"]
#  ['Tora! Tora! Tora! (1970)' 'War']
#  ['Pompatus of Love, The (1996)' 'Comedy|Drama']
#  ['Independence Day (ID4) (1996)' 'Action|Sci-Fi|War']]
#
# recommended items ids : [ 606 2250  646 2699 2020]
# recommened items :
#  [list(['Candyman: Farewell to the Flesh (1995)', 'Horror'])
#  list(["Men Don't Leave (1990)", 'Drama']) list(['Not in list'])
#  list(['Arachnophobia (1990)', 'Action|Comedy|Sci-Fi|Thriller'])
#  list(['Dangerous Liaisons (1988)', 'Drama|Romance'])]
# GOT IT!!!!
#
# recommended items ids : [2529 3354 3051 2638 2890]
# recommened items :
#  [['Planet of the Apes (1968)' 'Action|Sci-Fi']
#  ['Mission to Mars (2000)' 'Sci-Fi']
#  ['Anywhere But Here (1999)' 'Drama']
#  ["Mummy's Tomb, The (1942)" 'Horror']
#  ['Three Kings (1999)' 'Drama|War']]
# GOT IT!!!!
#
# recommended items ids : [3809 2230 2311 2676 3398]
# recommened items :
#  [['What About Bob? (1991)' 'Comedy']
#  ['Always Tell Your Wife (1923)' 'Comedy']
#  ['2010 (1984)' 'Mystery|Sci-Fi']
#  ['Instinct (1999)' 'Drama|Thriller']
#  ['Muppets Take Manhattan, The (1984)' "Children's|Comedy"]]
#
# recommended items ids : [ 286 2667   14 1718 1230]
# recommened items :
#  [['Nemesis 2: Nebula (1995)' 'Action|Sci-Fi|Thriller']
#  ['Mole People, The (1956)' 'Sci-Fi']
#  ['Nixon (1995)' 'Drama']
#  ['Stranger in the House (1997)' 'Thriller']
#  ['Annie Hall (1977)' 'Comedy|Romance']]
# GOT IT!!!!
# recommended items ids : [3512 3329 1744  868 3922]
# recommened items :
#  [['Return to Me (2000)' 'Drama|Romance']
#  ['Year My Voice Broke, The (1987)' 'Drama']
#  ['Firestorm (1998)' 'Action|Adventure|Thriller']
#  ['Death in Brunswick (1991)' 'Comedy']
#  ['Bikini Beach (1964)' 'Comedy']]
#
# recommended items ids : [ 846 1934 3133  755 2198]
# recommened items :
#  [['Flirt (1995)' 'Drama']
#  ["You Can't Take It With You (1938)" 'Comedy']
#  ['Go West (1925)' 'Comedy']
#  ['Kim (1950)' "Children's|Drama"]
#  ['Modulations (1998)' 'Documentary']]
#
# recommended items ids : [1840  758 3458 1704 2717]
# recommened items :
#  [['He Got Game (1998)' 'Drama']
#  ['Jar, The (Khomreh) (1992)' 'Drama']
#  ['Blood and Sand (Sangre y Arena) (1989)' 'Drama|Romance']
#  ['Good Will Hunting (1997)' 'Drama']
#  ['Ghostbusters II (1989)' 'Comedy|Horror']]
# GOT IT!!!!
#
# recommended items ids : [ 725 2544 1449  950 1833]
# recommened items :
#  [['Great White Hype, The (1996)' 'Comedy']
#  ["School of Flesh, The (L' École de la chair) (1998)" 'Drama']
#  ['Waiting for Guffman (1996)' 'Comedy']
#  ['Thin Man, The (1934)' 'Mystery']
#  ['Mercury Rising (1998)' 'Action|Drama|Thriller']]
#
# recommended items ids : [ 305  116 2549  891   38]
# recommened items :
#  [['Ready to Wear (Pret-A-Porter) (1994)' 'Comedy']
#  ['Anne Frank Remembered (1995)' 'Documentary']
#  ['Wing Commander (1999)' 'Action|Sci-Fi']
#  ['Halloween: The Curse of Michael Myers (1995)' 'Horror|Thriller']
#  ['It Takes Two (1995)' 'Comedy']]
#
# recommended items ids : [3094 2365  281 2601 3039]
# recommened items :
#  [['Maurice (1987)' 'Drama|Romance']
#  ['King Kong vs. Godzilla (Kingukongu tai Gojira) (1962)' 'Action|Sci-Fi']
#  ["Nobody's Fool (1994)" 'Drama']
#  ['Little Bit of Soul, A (1998)' 'Comedy']
#  ['Trading Places (1983)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [3268 2353 2098 2048 1827]
# recommened items :
#  [['Stop! Or My Mom Will Shoot (1992)' 'Action|Comedy']
#  ['Enemy of the State (1998)' 'Action|Thriller']
#  ['Son of Flubber (1963)' "Children's|Comedy"]
#  ['Great Mouse Detective, The (1986)' "Animation|Children's"]
#  ['Big One, The (1997)' 'Comedy|Documentary']]
#
# recommended items ids : [1629 3049 3056 1749 1640]
# recommened items :
#  [['MatchMaker, The (1997)' 'Comedy|Romance']
#  ['How I Won the War (1967)' 'Comedy|War']
#  ['Oxygen (1999)' 'Thriller']
#  ['Leading Man, The (1996)' 'Romance']
#  ['How to Be a Player (1997)' 'Comedy']]
#
# recommended items ids : [3491  677 1372 2169 1268]
# recommened items :
#  [list(['My Chauffeur (1986)', 'Comedy']) list(['Not in list'])
#  list(['Star Trek VI: The Undiscovered Country (1991)', 'Action|Adventure|Sci-Fi'])
#  list(['Dead Man on Campus (1998)', 'Comedy'])
#  list(['Pump Up the Volume (1990)', 'Drama'])]
#
# recommended items ids : [2897  786  947 3664 3936]
# recommened items :
#  [['And the Ship Sails On (E la nave va) (1984)' 'Comedy|War']
#  ['Eraser (1996)' 'Action|Thriller']
#  ['My Man Godfrey (1936)' 'Comedy']
#  ['Puppet Master 5: The Final Chapter (1994)' 'Horror|Sci-Fi|Thriller']
#  ['Phantom of the Opera, The (1943)' 'Drama|Thriller']]
#
# recommended items ids : [ 860  981 1064 1914  797]
# recommened items :
#  [['Maybe, Maybe Not (Bewegte Mann, Der) (1994)' 'Comedy']
#  ['Dangerous Ground (1997)' 'Drama']
#  ['Aladdin and the King of Thieves (1996)' "Animation|Children's|Comedy"]
#  ['Smoke Signals (1998)' 'Comedy|Drama']
#  ['Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)'
#   'Comedy']]
#
# recommended items ids : [1020  849 3136 3640 3174]
# recommened items :
#  [['Cool Runnings (1993)' 'Comedy']
#  ['Escape from L.A. (1996)' 'Action|Adventure|Sci-Fi|Thriller']
#  ['James Dean Story, The (1957)' 'Documentary']
#  ['King in New York, A (1957)' 'Comedy|Drama']
#  ['Man on the Moon (1999)' 'Comedy|Drama']]
#
# recommended items ids : [  27 2141 3440  967  858]
# recommened items :
#  [['Now and Then (1995)' 'Drama']
#  ['American Tail, An (1986)' "Animation|Children's|Comedy"]
#  ['Teenage Mutant Ninja Turtles III (1993)' "Action|Children's|Fantasy"]
#  ['Outlaw, The (1943)' 'Western']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']]
# GOT IT!!!!
#
# recommended items ids : [1779 2470  317 2630 1641]
# recommened items :
#  [['Sphere (1998)' 'Adventure|Sci-Fi|Thriller']
#  ['Crocodile Dundee (1986)' 'Adventure|Comedy']
#  ['Santa Clause, The (1994)' "Children's|Comedy|Fantasy"]
#  ["Besieged (L' Assedio) (1998)" 'Drama']
#  ['Full Monty, The (1997)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [3499 3861 1591 2069 1835]
# recommened items :
#  [['Misery (1990)' 'Horror']
#  ['Replacements, The (2000)' 'Comedy']
#  ['Spawn (1997)' 'Action|Adventure|Sci-Fi|Thriller']
#  ['Trip to Bountiful, The (1985)' 'Drama']
#  ['City of Angels (1998)' 'Romance']]
# GOT IT!!!!
#
# recommended items ids : [  83 2698  206 1551  279]
# recommened items :
#  [['Once Upon a Time... When We Were Colored (1995)' 'Drama']
#  ['Zone 39 (1997)' 'Sci-Fi']
#  ['Unzipped (1995)' 'Documentary']
#  ['Buddy (1997)' "Adventure|Children's|Drama"]
#  ['My Family (1995)' 'Drama']]
# GOT IT!!!!
#
# recommended items ids : [2202  550 1182 1381 3131]
# recommened items :
#  [list(['Lifeboat (1944)', 'Drama|Thriller|War'])
#  list(['Threesome (1994)', 'Comedy|Romance']) list(['Not in list'])
#  list(['Grease 2 (1982)', 'Comedy|Musical|Romance'])
#  list(['Broadway Damage (1997)', 'Comedy'])]
# GOT IT!!!!
#
# recommended items ids : [3053 1221 1878 2009  664]
# recommened items :
#  [['Messenger: The Story of Joan of Arc, The (1999)' 'Drama|War']
#  ['Godfather: Part II, The (1974)' 'Action|Crime|Drama']
#  ['Woo (1998)' 'Comedy|Romance']
#  ['Soylent Green (1973)' 'Sci-Fi|Thriller']
#  ['Faithful (1996)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [2262 1044  744 1881  473]
# recommened items :
#  [['About Last Night... (1986)' 'Comedy|Drama|Romance']
#  ['Surviving Picasso (1996)' 'Drama']
#  ['Brothers in Trouble (1995)' 'Drama']
#  ['Quest for Camelot (1998)' "Adventure|Animation|Children's|Fantasy"]
#  ['In the Army Now (1994)' 'Comedy|War']]
#
# recommended items ids : [ 809  488  736 3420 3322]
# recommened items :
#  [['Fled (1996)' 'Action|Adventure']
#  ['M. Butterfly (1993)' 'Drama']
#  ['Twister (1996)' 'Action|Adventure|Romance|Thriller']
#  ['...And Justice for All (1979)' 'Drama|Thriller']
#  ['3 Strikes (2000)' 'Comedy']]
#
# recommended items ids : [ 835 3759 2882 1275 1624]
# recommened items :
#  [['Foxfire (1996)' 'Drama']
#  ['Fun and Fancy Free (1947)' "Animation|Children's|Musical"]
#  ['Jakob the Liar (1999)' 'Drama']
#  ['Highlander (1986)' 'Action|Adventure']
#  ['Thousand Acres, A (1997)' 'Drama']]
#
# recommended items ids : [2231  902 2229  980 2055]
# recommened items :
#  [['Rounders (1998)' 'Crime|Drama']
#  ["Breakfast at Tiffany's (1961)" 'Drama|Romance']
#  ['Pleasure Garden, The (1925)' 'Drama']
#  ['In the Line of Duty 2 (1987)' 'Action']
#  ['Hot Lead and Cold Feet (1978)' 'Comedy|Western']]
#
# recommended items ids : [  88 3147 1538 2856 2490]
# recommened items :
#  [['Black Sheep (1996)' 'Comedy']
#  ['Green Mile, The (1999)' 'Drama|Thriller']
#  ['Second Jungle Book: Mowgli & Baloo, The (1997)' "Adventure|Children's"]
#  ['I Saw What You Did (1965)' 'Thriller']
#  ['Payback (1999)' 'Action|Thriller']]
#
# recommended items ids : [2330 1691 2849  734  101]
# recommened items :
#  [list(['Hands on a Hard Body (1996)', 'Documentary'])
#  list(['Not in list']) list(['Queens Logic (1991)', 'Comedy|Drama'])
#  list(['Getting Away With Murder (1996)', 'Comedy'])
#  list(['Bottle Rocket (1996)', 'Comedy'])]
#
# recommended items ids : [ 926  405 3360 1950 1422]
# recommened items :
#  [['All About Eve (1950)' 'Drama']
#  ['Highlander III: The Sorcerer (1994)' 'Action|Sci-Fi']
#  ['Hoosiers (1986)' 'Drama']
#  ['In the Heat of the Night (1967)' 'Drama|Mystery']
#  ['Murder at 1600 (1997)' 'Mystery|Thriller']]
# GOT IT!!!!
#
# recommended items ids : [2573  254  349  536  669]
# recommened items :
#  [['Tango (1998)' 'Drama']
#  ['Jefferson in Paris (1995)' 'Drama']
#  ['Clear and Present Danger (1994)' 'Action|Adventure|Thriller']
#  ['Simple Twist of Fate, A (1994)' 'Drama']
#  ['Aparajito (1956)' 'Drama']]
#
# recommended items ids : [ 573 3299 1276 3673 3279]
# recommened items :
#  [['Ciao, Professore! (Io speriamo che me la cavo ) (1993)' 'Drama']
#  ['Hanging Up (2000)' 'Comedy|Drama']
#  ['Cool Hand Luke (1967)' 'Comedy|Drama']
#  ['Benji the Hunted (1987)' "Adventure|Children's"]
#  ['Knockout (1999)' 'Action|Adventure']]
# GOT IT!!!!
#
# recommended items ids : [2187 2104 2752 1616 3181]
# recommened items :
#  [['Stage Fright (1950)' 'Mystery|Thriller']
#  ['Tex (1982)' 'Drama']
#  ['Outrageous Fortune (1987)' 'Comedy|Mystery']
#  ['Peacemaker, The (1997)' 'Action|Thriller|War']
#  ['Titus (1999)' 'Drama']]
#
# recommended items ids : [3930 2467 3324  802 2334]
# recommened items :
#  [['Creature From the Black Lagoon, The (1954)' 'Horror']
#  ['Name of the Rose, The (1986)' 'Mystery']
#  ['Drowning Mona (2000)' 'Comedy']
#  ['Phenomenon (1996)' 'Drama|Romance']
#  ['Siege, The (1998)' 'Action|Thriller']]
#
# recommended items ids : [1285  284 1571 3790 3117]
# recommened items :
#  [['Heathers (1989)' 'Comedy']
#  ['New York Cop (1996)' 'Action|Crime']
#  ['When the Cats Away (Chacun cherche son chat) (1996)' 'Comedy|Romance']
#  ['Groove (2000)' 'Drama']
#  ['Ride with the Devil (1999)' 'Drama|Romance|War']]
# GOT IT!!!!
#
# recommended items ids : [ 115 3353  978   52  519]
# recommened items :
#  [['Happiness Is in the Field (1995)' 'Comedy']
#  ['Closer You Get, The (2000)' 'Comedy|Romance']
#  ['Blue Angel, The (Blaue Engel, Der) (1930)' 'Drama']
#  ['Mighty Aphrodite (1995)' 'Comedy']
#  ['Robocop 3 (1993)' 'Sci-Fi|Thriller']]
# GOT IT!!!!
#
# recommended items ids : [ 346 1439 2976 2536 2097]
# recommened items :
#  [['Backbeat (1993)' 'Drama|Musical']
#  ['Meet Wally Sparks (1997)' 'Comedy']
#  ['Bringing Out the Dead (1999)' 'Drama|Horror']
#  ["Concorde: Airport '79, The (1979)" 'Drama']
#  ['Something Wicked This Way Comes (1983)' "Children's|Horror"]]
#
# recommended items ids : [2272 3150 3234 2688 2190]
# recommened items :
#  [['One True Thing (1998)' 'Drama']
#  ['War Zone, The (1999)' 'Drama']
#  ['Train Ride to Hollywood (1978)' 'Comedy']
#  ["General's Daughter, The (1999)" 'Drama|Thriller']
#  ['Why Do Fools Fall In Love? (1998)' 'Drama']]
#
# recommended items ids : [2914 2941 2428 2606 3928]
# recommened items :
#  [['Molly (1999)' 'Comedy|Drama']
#  ['South Pacific (1958)' 'Musical|Romance|War']
#  ['Faculty, The (1998)' 'Horror|Sci-Fi']
#  ['Idle Hands (1999)' 'Comedy|Horror']
#  ['Abbott and Costello Meet Frankenstein (1948)' 'Comedy|Horror']]
#
# recommended items ids : [ 303 2680   53 3832 3631]
# recommened items :
#  [['Quick and the Dead, The (1995)' 'Action|Adventure|Western']
#  ['Floating (1997)' 'Drama']
#  ['Lamerica (1994)' 'Drama']
#  ['Black Sabbath (Tre Volti Della Paura, I) (1963)' 'Horror']
#  ["It's in the Water (1998)" 'Comedy']]
#
# recommended items ids : [ 910 3547 2066   11  856]
# recommened items :
#  [['Some Like It Hot (1959)' 'Comedy|Crime']
#  ['Prick Up Your Ears (1987)' 'Drama']
#  ['Out of the Past (1947)' 'Film-Noir']
#  ['American President, The (1995)' 'Comedy|Drama|Romance']
#  ['Mille bolle blu (1993)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [1347 3153 3691 3708 1427]
# recommened items :
#  [['Nightmare on Elm Street, A (1984)' 'Horror']
#  ['7th Voyage of Sinbad, The (1958)' 'Action|Adventure|Fantasy']
#  ['Private School (1983)' 'Comedy']
#  ['Firestarter (1984)' 'Horror|Thriller']
#  ['Turbulence (1997)' 'Thriller']]
# GOT IT!!!!
#
# recommended items ids : [2551 3893 2358  347  475]
# recommened items :
#  [['Dead Ringers (1988)' 'Drama|Thriller']
#  ['Nurse Betty (2000)' 'Comedy|Thriller']
#  ['Savior (1998)' 'Drama']
#  ['Bitter Moon (1992)' 'Drama']
#  ['In the Name of the Father (1993)' 'Drama']]
#
# recommended items ids : [1280 1519 2063 1146 1992]
# recommened items :
#  [['Raise the Red Lantern (1991)' 'Drama']
#  ['Broken English (1996)' 'Drama']
#  ['Seventh Heaven (Le Septième ciel) (1997)' 'Drama|Romance']
#  ["Curtis's Charm (1995)" 'Comedy|Drama']
#  ["Child's Play 2 (1990)" 'Horror']]
#
# recommended items ids : [ 498 2430 1286  988  876]
# recommened items :
#  [['Mr. Jones (1993)' 'Drama|Romance']
#  ['Mighty Joe Young (1949)' "Adventure|Children's|Drama"]
#  ['Somewhere in Time (1980)' 'Drama|Romance']
#  ['Grace of My Heart (1996)' 'Comedy|Drama']
#  ['Police Story 4: Project S (Chao ji ji hua) (1993)' 'Action']]
# GOT IT!!!!
#
# recommended items ids : [3472 2632 2343 3854 2740]
# recommened items :
#  [['Horror Hotel (a.k.a. The City of the Dead) (1960)' 'Horror']
#  ['Saragossa Manuscript, The (Rekopis znaleziony w Saragossie) (1965)'
#   'Drama']
#  ['Naked Man, The (1998)' 'Drama']
#  ['Aimée & Jaguar (1999)' 'Drama|Romance']
#  ['Kindred, The (1986)' 'Horror']]
#
# recommended items ids : [1102 2998 1700 2452 2514]
# recommened items :
#  [list(['American Strays (1996)', 'Action'])
#  list(['Dreaming of Joseph Lees (1998)', 'Romance']) list(['Not in list'])
#  list(['Gate II: Trespassers, The (1990)', 'Horror'])
#  list(['Pet Sematary II (1992)', 'Horror'])]
# recommended items ids : [3908 2735  292 1028   72]
# recommened items :
#  [['Urban Legends: Final Cut (2000)' 'Horror']
#  ['Golden Child, The (1986)' 'Action|Adventure|Comedy']
#  ['Outbreak (1995)' 'Action|Drama|Thriller']
#  ['Mary Poppins (1964)' "Children's|Comedy|Musical"]
#  ['Kicking and Screaming (1995)' 'Comedy|Drama']]
# GOT IT!!!!
#
# recommended items ids : [  28 1225  920 1639  231]
# recommened items :
#  [['Persuasion (1995)' 'Romance']
#  ['Amadeus (1984)' 'Drama']
#  ['Gone with the Wind (1939)' 'Drama|Romance|War']
#  ['Chasing Amy (1997)' 'Drama|Romance']
#  ['Dumb & Dumber (1994)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [1642    3 1310  401 1115]
# recommened items :
#  [['Indian Summer (a.k.a. Alive & Kicking) (1996)' 'Comedy|Drama']
#  ['Grumpier Old Men (1995)' 'Comedy|Romance']
#  ['Hype! (1996)' 'Documentary']
#  ['Mirage (1995)' 'Action|Thriller']
#  ['Sleepover (1995)' 'Comedy|Drama']]
#
# recommended items ids : [1354  258 3940 1081 2577]
# recommened items :
#  [['Breaking the Waves (1996)' 'Drama']
#  ["Kid in King Arthur's Court, A (1995)"
#   "Adventure|Children's|Comedy|Fantasy|Romance"]
#  ['Slumber Party Massacre III, The (1990)' 'Horror']
#  ['Victor/Victoria (1982)' 'Comedy|Musical']
#  ['Metroland (1997)' 'Comedy|Drama']]
# GOT IT!!!!
#
# recommended items ids : [3695 1928 2534 2164  556]
# recommened items :
#  [['Toxic Avenger Part III: The Last Temptation of Toxie, The (1989)'
#   'Comedy|Horror']
#  ['Cimarron (1931)' 'Western']
#  ['Avalanche (1978)' 'Action']
#  ['Surf Nazis Must Die (1987)' 'Drama']
#  ['War Room, The (1993)' 'Documentary']]
# GOT IT!!!!
#
# recommended items ids : [3026 2643 2922 1468  722]
# recommened items :
#  [['Slaughterhouse (1987)' 'Horror']
#  ['Superman IV: The Quest for Peace (1987)' 'Action|Adventure|Sci-Fi']
#  ["Hang 'em High (1967)" 'Western']
#  ['Booty Call (1997)' 'Comedy|Romance']
#  ['Haunted World of Edward D. Wood Jr., The (1995)' 'Documentary']]
#
# recommended items ids : [ 214  893 3201 2019  655]
# recommened items :
#  [['Before the Rain (Pred dozhdot) (1994)' 'Drama']
#  ['Mother Night (1996)' 'Drama']
#  ['Five Easy Pieces (1970)' 'Drama']
#  ['Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)'
#   'Action|Drama']
#  ['Mutters Courage (1995)' 'Comedy']]
#
# recommended items ids : [1461 2304  424  643 1746]
# recommened items :
#  [['Vegas Vacation (1997)' 'Comedy']
#  ['Love Is the Devil (1998)' 'Drama']
#  ['Blue Chips (1994)' 'Drama']
#  ['Peanuts - Die Bank zahlt alles (1996)' 'Comedy']
#  ['Senseless (1998)' 'Comedy']]
#
# recommended items ids : [ 582  400 3012  195  123]
# recommened items :
#  [['Metisse (Café au Lait) (1993)' 'Comedy']
#  ['Homage (1995)' 'Drama']
#  ['Battling Butler (1926)' 'Comedy']
#  ['Something to Talk About (1995)' 'Comedy|Drama|Romance']
#  ['Chungking Express (1994)' 'Drama|Mystery|Romance']]
#
# recommended items ids : [ 238  383 2195 2653 1238]
# recommened items :
#  [['Far From Home: The Adventures of Yellow Dog (1995)'
#   "Adventure|Children's"]
#  ['Wyatt Earp (1994)' 'Western']
#  ['Dirty Work (1998)' 'Comedy']
#  ['Son of Dracula (1943)' 'Horror']
#  ['Local Hero (1983)' 'Comedy']]
#
# recommended items ids : [2639 2962   59 3933 3290]
# recommened items :
#  [['Mommie Dearest (1981)' 'Drama']
#  ['Fever Pitch (1997)' 'Comedy|Romance']
#  ['Confessional, The (Le Confessionnal) (1995)' 'Drama|Mystery']
#  ['Killer Shrews, The (1959)' 'Horror|Sci-Fi']
#  ['Soft Toilet Seats (1999)' 'Comedy']]
#
# recommended items ids : [ 630 3014 3233 1351  794]
# recommened items :
#  [['Carried Away (1996)' 'Drama|Romance']
#  ["Bustin' Loose (1981)" 'Comedy']
#  ['Smashing Time (1967)' 'Comedy']
#  ['Blood & Wine (1997)' 'Drama']
#  ['Midnight Dancers (Sibak) (1994)' 'Comedy|Drama']]
#
# recommended items ids : [3943  448  173  940 3156]
# recommened items :
#  [['Bamboozled (2000)' 'Comedy']
#  ['Fearless (1993)' 'Drama']
#  ['Judge Dredd (1995)' 'Action|Adventure|Sci-Fi']
#  ['Adventures of Robin Hood, The (1938)' 'Action|Adventure']
#  ['Bicentennial Man (1999)' 'Comedy|Drama|Sci-Fi']]
# GOT IT!!!!
#
# recommended items ids : [1731  929 3238 1156  321]
# recommened items :
#  [['Mr. Magoo (1997)' 'Comedy']
#  ['Foreign Correspondent (1940)' 'Thriller']
#  ['Eye of the Beholder (1999)' 'Thriller']
#  ['Children Are Watching us, The (Bambini ci guardano, I) (1942)' 'Drama']
#  ['Strawberry and Chocolate (Fresa y chocolate) (1993)' 'Drama']]
#
# recommended items ids : [2874 3501 1720  166 2075]
# recommened items :
#  [['Pajama Game, The (1957)' 'Comedy']
#  ["Murphy's Romance (1985)" 'Comedy|Romance']
#  ['Time Tracers (1995)' 'Action|Adventure|Sci-Fi']
#  ['Doom Generation, The (1995)' 'Comedy|Drama']
#  ['Mephisto (1981)' 'Drama|War']]
#
# recommended items ids : [1022  611 1033 3085  416]
# recommened items :
#  [['Cinderella (1950)' "Animation|Children's|Musical"]
#  ['Hellraiser: Bloodline (1996)' 'Action|Horror|Sci-Fi']
#  ['Fox and the Hound, The (1981)' "Animation|Children's"]
#  ['Living Dead Girl, The (La Morte Vivante) (1982)' 'Horror']
#  ['Bad Girls (1994)' 'Western']]
# GOT IT!!!!
#
# recommended items ids : [ 678 1012 2771 3867  105]
# recommened items :
#  [['Some Folks Call It a Sling Blade (1993)' 'Drama|Thriller']
#  ['Old Yeller (1957)' "Children's|Drama"]
#  ['Brokedown Palace (1999)' 'Drama']
#  ["All the Rage (a.k.a. It's the Rage) (1999)" 'Drama']
#  ['Bridges of Madison County, The (1995)' 'Drama|Romance']]
#
# recommended items ids : [3609 1632 3707 2828  552]
# recommened items :
#  [['Regret to Inform (1998)' 'Documentary']
#  ['Smile Like Yours, A (1997)' 'Comedy|Romance']
#  ['Nine 1/2 Weeks (1986)' 'Drama']
#  ['Dudley Do-Right (1999)' "Children's|Comedy"]
#  ['Three Musketeers, The (1993)' 'Action|Adventure|Comedy']]
#
# recommended items ids : [1281 1099 3008 3270 3061]
# recommened items :
#  [['Great Dictator, The (1940)' 'Comedy']
#  ['Christmas Carol, A (1938)' 'Drama']
#  ['Last Night (1998)' 'Thriller']
#  ['Cutting Edge, The (1992)' 'Drama']
#  ['Holiday Inn (1942)' 'Comedy|Musical']]
#
# recommended items ids : [ 125 3661 1903 2139 3058]
# recommened items :
#  [['Flirting With Disaster (1996)' 'Comedy']
#  ['Puppet Master II (1990)' 'Horror|Sci-Fi|Thriller']
#  ['Hav Plenty (1997)' 'Comedy']
#  ['Secret of NIMH, The (1982)' "Animation|Children's"]
#  ['Ape, The (1940)' 'Horror|Sci-Fi']]
#
# recommended items ids : [1759 3294 3347  961 2129]
# recommened items :
#  [['Four Days in September (1997)' 'Drama']
#  ['Eaten Alive (1976)' 'Horror']
#  ['Never Cry Wolf (1983)' 'Drama']
#  ['Little Lord Fauntleroy (1936)' 'Drama']
#  ['Saltmen of Tibet, The (1997)' 'Documentary']]
#
# recommended items ids : [ 187 1495 1592 3566  508]
# recommened items :
#  [['Party Girl (1995)' 'Comedy']
#  ['Turbo: A Power Rangers Movie (1997)' "Action|Adventure|Children's"]
#  ['Air Bud (1997)' "Children's|Comedy"]
#  ['Big Kahuna, The (2000)' 'Comedy|Drama']
#  ['Philadelphia (1993)' 'Drama']]
#
# recommended items ids : [ 804 3002 1886  492 2789]
# recommened items :
#  [["She's the One (1996)" 'Comedy|Romance']
#  ['My Best Fiend (Mein liebster Feind) (1999)' 'Documentary']
#  ['I Got the Hook Up (1998)' 'Comedy']
#  ['Manhattan Murder Mystery (1993)' 'Comedy|Mystery']
#  ['Damien: Omen II (1978)' 'Horror']]
#
# recommended items ids : [3721  143 3116 3069 1270]
# recommened items :
#  [['Trixie (1999)' 'Comedy']
#  ['Gospa (1995)' 'Drama']
#  ['Miss Julie (1999)' 'Drama']
#  ['Effect of Gamma Rays on Man-in-the-Moon Marigolds, The (1972)' 'Drama']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']]
# GOT IT!!!!
#
# recommended items ids : [  79 1201  245 2585  148]
# recommened items :
#  [['Juror, The (1996)' 'Drama|Thriller']
#  ['Good, The Bad and The Ugly, The (1966)' 'Action|Western']
#  ['Glass Shield, The (1994)' 'Crime|Drama']
#  ['Lovers of the Arctic Circle, The (Los Amantes del Círculo Polar) (1998)'
#   'Drama|Romance']
#  ['Awfully Big Adventure, An (1995)' 'Drama']]
#
# recommended items ids : [3703  665  939 3616  820]
# recommened items :
#  [['Mad Max 2 (a.k.a. The Road Warrior) (1981)' 'Action|Sci-Fi']
#  ['Underground (1995)' 'War']
#  ['Reluctant Debutante, The (1958)' 'Comedy|Drama']
#  ['Loser (2000)' 'Comedy|Romance']
#  ['Death in the Garden (Mort en ce jardin, La) (1956)' 'Drama']]
#
# recommended items ids : [1628  590 3851 3791 3774]
# recommened items :
#  [['Locusts, The (1997)' 'Drama']
#  ['Dances with Wolves (1990)' 'Adventure|Drama|Western']
#  ["I'm the One That I Want (2000)" 'Comedy']
#  ['Footloose (1984)' 'Drama']
#  ['House Party 2 (1991)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [ 908 1160 2449 2335 1398]
# recommened items :
#  [['North by Northwest (1959)' 'Drama|Thriller']
#  ['Six of a Kind (1934)' 'Comedy']
#  ['Garbage Pail Kids Movie, The (1987)' "Adventure|Children's"]
#  ['Waterboy, The (1998)' 'Comedy']
#  ['In Love and War (1996)' 'Romance|War']]
# GOT IT!!!!
#
# recommended items ids : [ 742 2843  160 1484 2505]
# recommened items :
#  [['Thinner (1996)' 'Horror|Thriller']
#  ['Black Cat, White Cat (Crna macka, beli macor) (1998)' 'Comedy|Romance']
#  ['Congo (1995)' 'Action|Adventure|Mystery|Sci-Fi']
#  ['Daytrippers, The (1996)' 'Mystery']
#  ['8MM (1999)' 'Thriller']]
#
# recommended items ids : [3099  441 3532 2841  657]
# recommened items :
#  [['Shampoo (1975)' 'Comedy|Romance']
#  ['Dazed and Confused (1993)' 'Comedy']
#  ['Freedom for Us (À nous la liberté ) (1931)' 'Comedy']
#  ['Stir of Echoes (1999)' 'Thriller']
#  ['Yankee Zulu (1994)' 'Comedy|Drama']]
# GOT IT!!!!
#
# recommended items ids : [3118 3021  179   69  877]
# recommened items :
#  [['Tumbleweeds (1999)' 'Drama']
#  ['Funhouse, The (1981)' 'Horror']
#  ['Mad Love (1995)' 'Drama|Romance']
#  ['Friday (1995)' 'Comedy']
#  ['Girls Town (1996)' 'Drama']]
#
# recommended items ids : [1760   42 1382   76 2383]
# recommened items :
#  [['Spice World (1997)' 'Comedy|Musical']
#  ['Dead Presidents (1995)' 'Action|Crime|Drama']
#  ['Marked for Death (1990)' 'Action|Drama']
#  ['Screamers (1995)' 'Sci-Fi|Thriller']
#  ['Police Academy 6: City Under Siege (1989)' 'Comedy']]
#
# recommended items ids : [3065  578 2664  619 3226]
# recommened items :
#  [['Ten Benny (1997)' 'Drama']
#  ['Hour of the Pig, The (1993)' 'Drama|Mystery']
#  ['Invasion of the Body Snatchers (1956)' 'Horror|Sci-Fi']
#  ['Ed (1996)' 'Comedy']
#  ['Hellhounds on My Trail (1999)' 'Documentary']]
# GOT IT!!!!
#
# recommended items ids : [ 937 3042 3005 3836 2207]
# recommened items :
#  [['Love in the Afternoon (1957)' 'Comedy|Romance']
#  ['Meatballs III (1987)' 'Comedy']
#  ['Bone Collector, The (1999)' 'Thriller']
#  ["Kelly's Heroes (1970)" 'Action|Comedy|War']
#  ['Jamaica Inn (1939)' 'Drama']]
#
# recommended items ids : [2173  253  930 1974 2486]
# recommened items :
#  [['Navigator: A Mediaeval Odyssey, The (1988)' 'Adventure|Fantasy|Sci-Fi']
#  ['Interview with the Vampire (1994)' 'Drama|Horror']
#  ['Notorious (1946)' 'Film-Noir|Romance|Thriller']
#  ['Friday the 13th (1980)' 'Horror']
#  ['24-hour Woman (1998)' 'Drama']]
# GOT IT!!!!
#
# recommended items ids : [ 571 1937 1794  841  859]
# recommened items :
#  [['Wedding Gift, The (1994)' 'Drama']
#  ['Going My Way (1944)' 'Comedy']
#  ['Love and Death on Long Island (1997)' 'Comedy|Drama']
#  ['Eyes Without a Face (1959)' 'Horror']
#  ['Hippie Revolution, The (1996)' 'Documentary']]
#
# recommended items ids : [1523 2094 2547 1729 1246]
# recommened items :
#  [['Truth or Consequences, N.M. (1997)' 'Action|Crime|Romance']
#  ['Rocketeer, The (1991)' 'Action|Adventure|Sci-Fi']
#  ['Harvest (1998)' 'Drama']
#  ['Jackie Brown (1997)' 'Crime|Drama']
#  ['Dead Poets Society (1989)' 'Drama']]
#
# recommended items ids : [1710 1715  689 2446 2348]
# recommened items :
#  [list(['Man of Her Dreams (1996)', 'Drama'])
#  list(['Office Killer (1997)', 'Thriller']) list(['Not in list'])
#  list(['In Dreams (1999)', 'Thriller'])
#  list(['Sid and Nancy (1986)', 'Drama'])]
#
# recommended items ids : [ 394 3595 3135  832 3091]
# recommened items :
#  [['Coldblooded (1995)' 'Action']
#  ['Held Up (2000)' 'Comedy']
#  ['Great Santini, The (1979)' 'Drama']
#  ['Ransom (1996)' 'Drama|Thriller']
#  ['Kagemusha (1980)' 'Drama|War']]
#
# recommended items ids : [ 667  355 3167 3555 3115]
# recommened items :
#  [['Bloodsport 2 (1995)' 'Action']
#  ['Flintstones, The (1994)' "Children's|Comedy"]
#  ['Carnal Knowledge (1971)' 'Drama']
#  ['U-571 (2000)' 'Action|Thriller']
#  ['Flawless (1999)' 'Drama']]
#
# recommended items ids : [2560 2033 2367 3680  666]
# recommened items :
#  [['Ravenous (1999)' 'Drama|Horror']
#  ['Black Cauldron, The (1985)' "Animation|Children's"]
#  ['King Kong (1976)' 'Action|Adventure|Horror']
#  ['Decline of Western Civilization Part II: The Metal Years, The (1988)'
#   'Documentary']
#  ['All Things Fair (1996)' 'Drama']]
# GOT IT!!!!
#
# recommended items ids : [3629 3484  924 1198  343]
# recommened items :
#  [['Gold Rush, The (1925)' 'Comedy']
#  ['Skulls, The (2000)' 'Thriller']
#  ['2001: A Space Odyssey (1968)' 'Drama|Mystery|Sci-Fi|Thriller']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']
#  ['Baby-Sitters Club, The (1995)' "Children's"]]
# GOT IT!!!!
# recommended items ids : [1336 2342 3858 2964  934]
# recommened items :
#  [['Body Parts (1991)' 'Horror']
#  ['Hard Core Logo (1996)' 'Comedy']
#  ['Cecil B. Demented (2000)' 'Comedy']
#  ['Julien Donkey-Boy (1999)' 'Drama']
#  ['Father of the Bride (1950)' 'Comedy']]
#
# recommended items ids : [3374  107 3909 2497 3011]
# recommened items :
#  [['Daughters of the Dust (1992)' 'Drama']
#  ['Muppet Treasure Island (1996)' "Adventure|Children's|Comedy|Musical"]
#  ['Woman on Top (2000)' 'Comedy|Romance']
#  ['Message in a Bottle (1999)' 'Romance']
#  ["They Shoot Horses, Don't They? (1969)" 'Drama']]
#
# recommended items ids : [2582 1733  773 3258 3003]
# recommened items :
#  [['Twin Dragons (Shuang long hui) (1992)' 'Action|Comedy']
#  ['Afterglow (1997)' 'Drama|Romance']
#  ['Touki Bouki (Journey of the Hyena) (1973)' 'Drama']
#  ['Death Becomes Her (1992)' 'Comedy']
#  ['Train of Life (Train De Vie) (1998)' 'Comedy|Drama']]
#
# recommended items ids : [2807 2316 2001 1987 3810]
# recommened items :
#  [['Universal Soldier: The Return (1999)' 'Action|Sci-Fi']
#  ['Practical Magic (1998)' 'Drama|Romance']
#  ['Lethal Weapon 2 (1989)' 'Action|Comedy|Crime|Drama']
#  ['Prom Night (1980)' 'Horror']
#  ['White Sands (1992)' 'Drama|Thriller']]
# GOT IT!!!!
#
# recommended items ids : [1242 3526 2708  363 1821]
# recommened items :
#  [['Glory (1989)' 'Action|Drama|War']
#  ['Parenthood (1989)' 'Comedy|Drama']
#  ["Autumn Tale, An (Conte d'automne) (1998)" 'Romance']
#  ['Wonderful, Horrible Life of Leni Riefenstahl, The (Die Macht der Bilder) (1993)'
#   'Documentary']
#  ['Object of My Affection, The (1998)' 'Comedy|Romance']]
# GOT IT!!!!
#
# recommended items ids : [2923  100 2727  234 1955]
# recommened items :
#  [["Citizen's Band (a.k.a. Handle with Care) (1977)" 'Comedy']
#  ['City Hall (1996)' 'Drama|Thriller']
#  ["Killer's Kiss (1955)" 'Film-Noir']
#  ['Exit to Eden (1994)' 'Comedy']
#  ['Kramer Vs. Kramer (1979)' 'Drama']]
# GOT IT!!!!
#
# recommended items ids : [2320  478 1362   68 1505]
# recommened items :
#  [list(['Apt Pupil (1998)', 'Drama|Thriller'])
#  list(['Jimmy Hollywood (1994)', 'Comedy'])
#  list(['Garden of Finzi-Contini, The (Giardino dei Finzi-Contini, Il) (1970)', 'Drama'])
#  list(['French Twist (Gazon maudit) (1995)', 'Comedy|Romance'])
#  list(['Not in list'])]
#
# recommended items ids : [2770 3789    7 1261 3623]
# recommened items :
#  [['Bowfinger (1999)' 'Comedy']
#  ['Pawnbroker, The (1965)' 'Drama']
#  ['Sabrina (1995)' 'Comedy|Romance']
#  ['Evil Dead II (Dead By Dawn) (1987)' 'Action|Adventure|Comedy|Horror']
#  ['Mission: Impossible 2 (2000)' 'Action|Thriller']]
#
# recommended items ids : [2051  267 2762 1561 2886]
# recommened items :
#  [['Herbie Goes to Monte Carlo (1977)' "Adventure|Children's|Comedy"]
#  ['Major Payne (1994)' 'Comedy']
#  ['Sixth Sense, The (1999)' 'Thriller']
#  ['Wedding Bell Blues (1996)' 'Comedy']
#  ['Adventures of Elmo in Grouchland, The (1999)' "Children's|Comedy"]]
#
# precision : 0.3656716417910448, episode_reward : -8
