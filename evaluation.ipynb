# %%
#Dependencies
import pandas as pd
import numpy as np
import tensorflow as tf
import itertools
import matplotlib.pyplot as plt
import time

from envs import OfflineEnv
from recommender import DRRAgent

import os

ROOT_DIR = os.getcwd()
DATA_DIR = os.path.join(ROOT_DIR, 'ml-1m/')
STATE_SIZE = 10

# %%
def evaluate(recommender, env, top_k=False):

        recommender.load_model('/home/diominor/Workspace/DRR/save_weights/actor_7000.h5', '/home/diominor/Workspace/DRR/save_weights/critic_7000.h5')

        # episodic reward 리셋
        episode_reward = 0
        correct_count = 0
        steps = 0
        # Environment 리셋
        user_id, items_ids, done = env.reset()
        print(f'user_id : {user_id}, rated_items_length:{len(env.user_items)}')
        print('items : \n', np.array(env.get_items_names(items_ids)))
        
        while not done:
            
            # Observe current state & Find action
            ## Embedding 해주기
            user_id = tf.convert_to_tensor(user_id)
            items_ids = tf.convert_to_tensor(items_ids)
            user_eb, items_eb = recommender.actor.embedding_network(user_id, items_ids)
            user_eb = tf.reshape(user_eb, (1,1, *user_eb.shape))
            items_eb = tf.reshape(items_eb, (1,*items_eb.shape))
            ## Action(ranking score) 출력
            action, _ = recommender.actor.network(user_eb, items_eb)
            ## Item 추천
            recommended_item = recommender.actor.recommend_item(action, env.recommended_items, top_k=top_k, is_test=True)
            print(f'recommended items ids : {recommended_item}')
            print(f'recommened items : \n {np.array(env.get_items_names(recommended_item), dtype=object)}')
            # Calculate reward & observe new state (in env)
            ## Step
            next_items_ids, reward, done, _ = env.step(recommended_item, top_k=top_k)
            items_ids = next_items_ids
            episode_reward += reward
            steps += 1
            if reward > 0:
                correct_count += 1
                print('GOT IT!!!!')
            print()  

        print(f'precision : {correct_count/steps}, episode_reward : {episode_reward}')
        print()

# %%
#Loading datasets
ratings_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'ratings.dat'), 'r').readlines()]
users_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'users.dat'), 'r').readlines()]
movies_list = [i.strip().split("::") for i in open(os.path.join(DATA_DIR,'movies.dat'),encoding='latin-1').readlines()]
ratings_df = pd.DataFrame(ratings_list, columns = ['UserID', 'MovieID', 'Rating', 'Timestamp'], dtype = np.uint32)
movies_df = pd.DataFrame(movies_list, columns = ['MovieID', 'Title', 'Genres'])
movies_df['MovieID'] = movies_df['MovieID'].apply(pd.to_numeric)

# %%
# 영화 id를 영화 제목으로
movies_id_to_movies = {movie[0]: movie[1:] for movie in movies_list}

# %%
len(movies_list)
# Out:
# 3883

# %%
ratings_df.head(5)
# Out:
#   UserID MovieID Rating  Timestamp
# 0      1    1193      5  978300760
# 1      1     661      3  978302109
# 2      1     914      3  978301968
# 3      1    3408      4  978300275
# 4      1    2355      5  978824291

# %%
# # 사용자가 선택한 영화 분포 확인
# plt.figure(figsize=(20,10))
# plt.hist(ratings_df["MovieID"], bins=3883)
# plt.show()

# %%
# 결측치 확인
ratings_df.isnull().sum()
# Out:
# UserID       0
# MovieID      0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
# 최대값 확인
print(len(set(ratings_df["UserID"])) == max([int(i) for i in set(ratings_df["UserID"])]))
print(max([int(i) for i in set(ratings_df["UserID"])]))
# Out:
# True
# 6040

# %%
ratings_df = ratings_df.applymap(int)

# %%
# 유저별로 본 영화들 순서대로 정리
users_dict = {user : [] for user in set(ratings_df["UserID"])}
users_dict[1]
# Out:
# []

# %%
# 시간 순으로 정렬하기
ratings_df = ratings_df.sort_values(by='Timestamp', ascending=True)
ratings_df.head(5)
# Out:
#          UserID  MovieID  Rating  Timestamp
# 1000138    6040      858       4  956703932
# 1000153    6040     2384       4  956703954
# 999873     6040      593       5  956703954
# 1000007    6040     1961       4  956703977
# 1000192    6040     2019       5  956703977

# %%
# 유저 딕셔너리에 (영화, 평점)쌍 넣기
ratings_df_gen = ratings_df.iterrows()
for data in ratings_df_gen:
    users_dict[data[1]['UserID']].append((data[1]['MovieID'], data[1]['Rating']))
users_dict[1]
# Out:
# [(3186, 4),
#  (1721, 4),
#  (1270, 5),
#  (1022, 5),
#  (2340, 3),
#  (1836, 5),
#  (3408, 4),
#  (1207, 4),
#  (2804, 5),
#  (260, 4),
#  (720, 3),
#  (1193, 5),
#  (919, 4),
#  (608, 4),
#  (2692, 4),
#  (1961, 5),
#  (2028, 5),
#  (3105, 5),
#  (938, 4),
#  (1035, 5),
#  (1962, 4),
#  (1028, 5),
#  (2018, 4),
#  (150, 5),
#  (1097, 4),
#  (914, 3),
#  (1287, 5),
#  (2797, 4),
#  (1246, 4),
#  (2762, 4),
#  (661, 3),
#  (2918, 4),
#  (531, 4),
#  (3114, 4),
#  (2791, 4),
#  (1029, 5),
#  (2321, 3),
#  (1197, 3),
#  (594, 4),
#  (2398, 4),
#  (1545, 4),
#  (527, 5),
#  (745, 3),
#  (595, 5),
#  (588, 4),
#  (1, 5),
#  (2687, 3),
#  (783, 4),
#  (2294, 4),
#  (2355, 5),
#  (1907, 4),
#  (1566, 4),
#  (48, 5)]

# %%
# 각 유저별 영화 히스토리 길이
users_history_lens = [len(users_dict[u]) for u in set(ratings_df["UserID"])]
users_history_lens[:10]
# Out:
# [53, 129, 51, 21, 198, 71, 31, 139, 106, 401]

# %%
users_dict[1]
# Out:
# [(3186, 4),
#  (1721, 4),
#  (1270, 5),
#  (1022, 5),
#  (2340, 3),
#  (1836, 5),
#  (3408, 4),
#  (1207, 4),
#  (2804, 5),
#  (260, 4),
#  (720, 3),
#  (1193, 5),
#  (919, 4),
#  (608, 4),
#  (2692, 4),
#  (1961, 5),
#  (2028, 5),
#  (3105, 5),
#  (938, 4),
#  (1035, 5),
#  (1962, 4),
#  (1028, 5),
#  (2018, 4),
#  (150, 5),
#  (1097, 4),
#  (914, 3),
#  (1287, 5),
#  (2797, 4),
#  (1246, 4),
#  (2762, 4),
#  (661, 3),
#  (2918, 4),
#  (531, 4),
#  (3114, 4),
#  (2791, 4),
#  (1029, 5),
#  (2321, 3),
#  (1197, 3),
#  (594, 4),
#  (2398, 4),
#  (1545, 4),
#  (527, 5),
#  (745, 3),
#  (595, 5),
#  (588, 4),
#  (1, 5),
#  (2687, 3),
#  (783, 4),
#  (2294, 4),
#  (2355, 5),
#  (1907, 4),
#  (1566, 4),
#  (48, 5)]

# %%
users_num = max(ratings_df["UserID"])+1
items_num = max(ratings_df["MovieID"])+1

# %%
print(users_num, items_num)
# Out:
# 6041 3953

# %% [markdown]
# ### 준비된것
# users_dict, users_history_len, movies_id_to_movies, sers_num, items_num

# %%
tf.keras.backend.set_floatx('float64')

# %%
env = OfflineEnv(users_dict, users_history_lens, movies_id_to_movies, STATE_SIZE)
recommender = DRRAgent(env, users_num, items_num, STATE_SIZE)
recommender.actor.build_networks()
recommender.critic.build_networks()
evaluate(recommender, env, top_k=20)
# Out:
# user_id : 3081, rated_items_length:384
# items :
#  [['Big Trouble in Little China (1986)' 'Action|Comedy']
#  ["One Flew Over the Cuckoo's Nest (1975)" 'Drama']
#  ['Pelican Brief, The (1993)' 'Thriller']
#  ['Clockwork Orange, A (1971)' 'Sci-Fi']
#  ['Rocky III (1982)' 'Action|Drama']
#  ['Back to the Future (1985)' 'Comedy|Sci-Fi']
#  ['Star Wars: Episode IV - A New Hope (1977)'
#   'Action|Adventure|Fantasy|Sci-Fi']
#  ['Godfather: Part II, The (1974)' 'Action|Crime|Drama']
#  ['Godfather, The (1972)' 'Action|Crime|Drama']
#  ['Raiders of the Lost Ark (1981)' 'Action|Adventure']]
# recommended items ids : [3240 3400 2199 1809  999 1145 3761 1073   42    8 1366 1295 2911 1491
#  2992 1832  253  569 2467 2726]
# recommened items :
#  [list(['Big Tease, The (1999)', 'Comedy'])
#  list(["We're Back! A Dinosaur's Story (1993)", "Animation|Children's"])
#  list(['Phoenix (1998)', 'Crime|Drama'])
#  list(['Hana-bi (1997)', 'Comedy|Crime|Drama'])
#  list(['2 Days in the Valley (1996)', 'Crime'])
#  list(['Snowriders (1996)', 'Documentary'])
#  list(['Blood In, Blood Out (a.k.a. Bound by Honor) (1993)', 'Crime|Drama'])
#  list(['Willy Wonka and the Chocolate Factory (1971)', "Adventure|Children's|Comedy|Fantasy"])
#  list(['Dead Presidents (1995)', 'Action|Crime|Drama'])
#  list(['Tom and Huck (1995)', "Adventure|Children's"])
#  list(['Crucible, The (1996)', 'Drama'])
#  list(['Unbearable Lightness of Being, The (1988)', 'Drama'])
#  list(['Grandfather, The (El Abuelo) (1998)', 'Drama'])
#  list(['Not in list']) list(['Rawhead Rex (1986)', 'Horror|Thriller'])
#  list(["Heaven's Burning (1997)", 'Action|Drama'])
#  list(['Interview with the Vampire (1994)', 'Drama|Horror'])
#  list(['Little Big League (1994)', "Children's|Comedy"])
#  list(['Name of the Rose, The (1986)', 'Mystery'])
#  list(['Killing, The (1956)', 'Crime|Film-Noir'])]
# GOT IT!!!!
#
# recommended items ids : [1308  199  158 1284 2306 2279 1710 2528  868 2409 3406  809 3112 1273
#  2593  190  408 3679 1194 2962]
# recommened items :
#  [['I Shot a Man in Vegas (1995)' 'Comedy']
#  ['Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)'
#   'Drama|Musical']
#  ['Casper (1995)' "Adventure|Children's"]
#  ['Big Sleep, The (1946)' 'Film-Noir|Mystery']
#  ['Holy Man (1998)' 'Comedy']
#  ['Urban Legend (1998)' 'Horror|Thriller']
#  ['Man of Her Dreams (1996)' 'Drama']
#  ["Logan's Run (1976)" 'Action|Adventure|Sci-Fi']
#  ['Death in Brunswick (1991)' 'Comedy']
#  ['Rocky II (1979)' 'Action|Drama']
#  ['Captain Horatio Hornblower (1951)' 'Action|Adventure|War']
#  ['Fled (1996)' 'Action|Adventure']
#  ["'Night Mother (1986)" 'Drama']
#  ['Down by Law (1986)' 'Comedy|Drama']
#  ['Monster, The (Il Mostro) (1994)' 'Comedy']
#  ['Safe (1995)' 'Thriller']
#  ['8 Seconds (1994)' 'Drama']
#  ['Decline of Western Civilization, The (1981)' 'Documentary']
#  ['Up in Smoke (1978)' 'Comedy']
#  ['Fever Pitch (1997)' 'Comedy|Romance']]
# GOT IT!!!!
#
# recommended items ids : [1113  407 3252 3371 3846 3229  348 2350  882  234 3098  183 2087 3611
#   562 3070  106 1650 3198 1510]
# recommened items :
#  [['Associate, The (1996)' 'Comedy']
#  ['In the Mouth of Madness (1995)' 'Horror|Thriller']
#  ['Scent of a Woman (1992)' 'Drama']
#  ['Bound for Glory (1976)' 'Drama']
#  ['Easy Money (1983)' 'Comedy']
#  ["Another Man's Poison (1952)" 'Crime|Drama']
#  ['Bullets Over Broadway (1994)' 'Comedy']
#  ['Heart Condition (1990)' 'Comedy']
#  ['Trigger Effect, The (1996)' 'Drama|Thriller']
#  ['Exit to Eden (1994)' 'Comedy']
#  ['Natural, The (1984)' 'Drama']
#  ['Mute Witness (1994)' 'Thriller']
#  ['Peter Pan (1953)' "Animation|Children's|Fantasy|Musical"]
#  ['Saludos Amigos (1943)' "Animation|Children's|Comedy"]
#  ['Welcome to the Dollhouse (1995)' 'Comedy|Drama']
#  ['Adventures of Buckaroo Bonzai Across the 8th Dimension, The (1984)'
#   'Adventure|Comedy|Sci-Fi']
#  ['Nobody Loves Me (Keiner liebt mich) (1994)' 'Comedy|Drama']
#  ['Washington Square (1997)' 'Drama']
#  ['Papillon (1973)' 'Drama']
#  ["Brother's Kiss, A (1997)" 'Drama']]
# GOT IT!!!!
#
# recommended items ids : [1560 2015   47 2007  298 2975 2770 2945  804  591 2298 3178  499 3581
#  1786 3707 3601  567 2382 1422]
# recommened items :
#  [list(['Not in list'])
#  list(['Absent Minded Professor, The (1961)', "Children's|Comedy|Fantasy"])
#  list(['Seven (Se7en) (1995)', 'Crime|Thriller'])
#  list(['Polish Wedding (1998)', 'Comedy'])
#  list(['Pushing Hands (1992)', 'Comedy'])
#  list(['Best Man, The (1999)', 'Drama'])
#  list(['Bowfinger (1999)', 'Comedy'])
#  list(["Mike's Murder (1984)", 'Mystery'])
#  list(["She's the One (1996)", 'Comedy|Romance'])
#  list(['Tough and Deadly (1995)', 'Action|Drama|Thriller'])
#  list(['Strangeland (1998)', 'Thriller'])
#  list(['Hurricane, The (1999)', 'Drama'])
#  list(['Mr. Wonderful (1993)', 'Comedy|Romance'])
#  list(['Human Traffic (1999)', 'Drama']) list(['Not in list'])
#  list(['Nine 1/2 Weeks (1986)', 'Drama'])
#  list(['Castaway Cowboy, The (1974)', 'Comedy|Western'])
#  list(['Kika (1993)', 'Drama'])
#  list(['Police Academy 5: Assignment: Miami Beach (1988)', 'Comedy'])
#  list(['Murder at 1600 (1997)', 'Mystery|Thriller'])]
# GOT IT!!!!
#
# recommended items ids : [3806  222 2955 3370 3926 2066 2091  971 2657 3875 1724 3037  342 3282
#  2243  695 3433  483  473 3820]
# recommened items :
#  [["MacKenna's Gold (1969)" 'Western']
#  ['Circle of Friends (1995)' 'Drama|Romance']
#  ['Penitentiary II (1982)' 'Drama']
#  ['Betrayed (1988)' 'Drama|Thriller']
#  ['Voyage to the Bottom of the Sea (1961)' 'Adventure|Sci-Fi']
#  ['Out of the Past (1947)' 'Film-Noir']
#  ['Return from Witch Mountain (1978)' "Children's|Sci-Fi"]
#  ['Cat on a Hot Tin Roof (1958)' 'Drama']
#  ['Rocky Horror Picture Show, The (1975)' 'Comedy|Horror|Musical|Sci-Fi']
#  ['Devil Rides Out, The (1968)' 'Horror']
#  ['Full Speed (1996)' 'Drama']
#  ['Little Big Man (1970)' 'Comedy|Drama|Western']
#  ["Muriel's Wedding (1994)" 'Comedy|Romance']
#  ['Different for Girls (1996)' 'Comedy']
#  ['Broadcast News (1987)' 'Comedy|Drama|Romance']
#  ['True Crime (1995)' 'Mystery|Thriller']
#  ['Death Wish 4: The Crackdown (1987)' 'Action|Drama']
#  ['King of the Hill (1993)' 'Drama']
#  ['In the Army Now (1994)' 'Comedy|War']
#  ['Thomas and the Magic Railroad (2000)' "Children's"]]
# GOT IT!!!!
#
# recommended items ids : [1908 3352 2018 2953 3479 3731 2113 2936 2490  764 1469 1667 2462  670
#  2898 1051  963  608 1906 2155]
# recommened items :
#  [list(['Resurrection Man (1998)', 'Drama|Thriller'])
#  list(["Brown's Requiem (1998)", 'Drama'])
#  list(['Bambi (1942)', "Animation|Children's"])
#  list(['Home Alone 2: Lost in New York (1992)', "Children's|Comedy"])
#  list(['Ladyhawke (1985)', 'Adventure|Fantasy|Romance'])
#  list(["Cutter's Way (1981)", 'Drama|Thriller'])
#  list(['Graveyard Shift (1990)', 'Horror|Thriller'])
#  list(["Sullivan's Travels (1942)", 'Comedy'])
#  list(['Payback (1999)', 'Action|Thriller'])
#  list(['Heavy (1995)', 'Drama|Romance']) list(['Not in list'])
#  list(['Mad City (1997)', 'Action|Drama'])
#  list(['Return of the Texas Chainsaw Massacre, The (1994)', 'Horror'])
#  list(['World of Apu, The (Apur Sansar) (1959)', 'Drama'])
#  list(['Dark Half, The (1993)', 'Horror|Mystery'])
#  list(['Trees Lounge (1996)', 'Drama'])
#  list(['Inspector General, The (1949)', 'Musical'])
#  list(['Fargo (1996)', 'Crime|Drama|Thriller'])
#  list(['Mr. Jealousy (1997)', 'Comedy|Romance'])
#  list(['Slums of Beverly Hills, The (1998)', 'Comedy'])]
# GOT IT!!!!
#
# recommended items ids : [1310  748 2265  891 3254  774 1372  432 2602 3311 2837 1027 2981 2185
#    81  547  466  803  910 3167]
# recommened items :
#  [['Hype! (1996)' 'Documentary']
#  ['Arrival, The (1996)' 'Action|Sci-Fi|Thriller']
#  ['Nothing But Trouble (1991)' 'Adventure|Comedy']
#  ['Halloween: The Curse of Michael Myers (1995)' 'Horror|Thriller']
#  ["Wayne's World 2 (1993)" 'Comedy']
#  ["Wend Kuuni (God's Gift) (1982)" 'Drama']
#  ['Star Trek VI: The Undiscovered Country (1991)'
#   'Action|Adventure|Sci-Fi']
#  ["City Slickers II: The Legend of Curly's Gold (1994)" 'Comedy|Western']
#  ['Mighty Peking Man (Hsing hsing wang) (1977)' 'Adventure|Sci-Fi']
#  ['Man from Laramie, The (1955)' 'Western']
#  ['Bedrooms & Hallways (1998)' 'Comedy|Romance']
#  ['Robin Hood: Prince of Thieves (1991)' 'Drama']
#  ['Brother, Can You Spare a Dime? (1975)' 'Documentary']
#  ['I Confess (1953)' 'Thriller']
#  ["Things to Do in Denver when You're Dead (1995)" 'Crime|Drama|Romance']
#  ['Surviving the Game (1994)' 'Action|Adventure|Thriller']
#  ['Hot Shots! Part Deux (1993)' 'Action|Comedy|War']
#  ['Walking and Talking (1996)' 'Romance']
#  ['Some Like It Hot (1959)' 'Comedy|Crime']
#  ['Carnal Knowledge (1971)' 'Drama']]
#
# recommended items ids : [ 528  661 2696 2181 1057 1263 2077 3767 1454  633 1640 2520  902 3005
#  2050 2292 1790 3615 2867 2751]
# recommened items :
#  [list(['Scout, The (1994)', 'Drama'])
#  list(['James and the Giant Peach (1996)', "Animation|Children's|Musical"])
#  list(['Dinner Game, The (Le Dîner de cons) (1998)', 'Comedy'])
#  list(['Marnie (1964)', 'Thriller'])
#  list(['Everyone Says I Love You (1996)', 'Comedy|Musical|Romance'])
#  list(['Deer Hunter, The (1978)', 'Drama|War'])
#  list(['Journey of Natty Gann, The (1985)', "Adventure|Children's"])
#  list(['Missing in Action 2: The Beginning (1985)', 'Action|War'])
#  list(['SubUrbia (1997)', 'Comedy'])
#  list(['Denise Calls Up (1995)', 'Comedy'])
#  list(['How to Be a Player (1997)', 'Comedy'])
#  list(['Airport (1970)', 'Drama'])
#  list(["Breakfast at Tiffany's (1961)", 'Drama|Romance'])
#  list(['Bone Collector, The (1999)', 'Thriller'])
#  list(['Herbie Goes Bananas (1980)', "Adventure|Children's|Comedy"])
#  list(['Overnight Delivery (1996)', 'Romance']) list(['Not in list'])
#  list(['Dinosaur (2000)', "Animation|Children's"])
#  list(['Fright Night (1985)', 'Comedy|Horror'])
#  list(['From the Hip (1987)', 'Comedy'])]
# GOT IT!!!!
#
# recommended items ids : [2806 1785 3220 1835 2315 1558 1964   94 1854 2839 3842  578 1781  563
#  1904 2124 2311 2859 2503 3937]
# recommened items :
#  [['Teaching Mrs. Tingle (1999)' 'Comedy|Thriller']
#  ['King of New York (1990)' 'Action|Crime']
#  ['Night Tide (1961)' 'Drama']
#  ['City of Angels (1998)' 'Romance']
#  ['Bride of Chucky (1998)' 'Horror|Thriller']
#  ['Sudden Manhattan (1996)' 'Comedy']
#  ['Klute (1971)' 'Drama|Mystery']
#  ['Beautiful Girls (1996)' 'Drama']
#  ['Kissing a Fool (1998)' 'Comedy|Romance']
#  ['West Beirut (West Beyrouth) (1998)' 'Drama']
#  ['Make Them Die Slowly (Cannibal Ferox) (1980)' 'Horror']
#  ['Hour of the Pig, The (1993)' 'Drama|Mystery']
#  ['Further Gesture, A (1996)' 'Drama']
#  ['Germinal (1993)' 'Drama']
#  ['Henry Fool (1997)' 'Comedy|Drama']
#  ['Addams Family, The (1991)' 'Comedy']
#  ['2010 (1984)' 'Mystery|Sci-Fi']
#  ['Stop Making Sense (1984)' 'Documentary']
#  ['Apple, The (Sib) (1998)' 'Drama']
#  ['Runaway (1984)' 'Sci-Fi|Thriller']]
#
# recommended items ids : [2132 1690  457  756  174 3817 3751  595  404 1098  581 1873 3554 3734
#  1028  658 2468 1445  719 1025]
# recommened items :
#  [["Who's Afraid of Virginia Woolf? (1966)" 'Drama']
#  ['Alien: Resurrection (1997)' 'Action|Horror|Sci-Fi']
#  ['Fugitive, The (1993)' 'Action|Thriller']
#  ['Carmen Miranda: Bananas Is My Business (1994)' 'Documentary']
#  ['Jury Duty (1995)' 'Comedy']
#  ['Other Side of Sunday, The (Søndagsengler) (1996)' 'Comedy|Drama']
#  ['Chicken Run (2000)' "Animation|Children's|Comedy"]
#  ['Beauty and the Beast (1991)' "Animation|Children's|Musical"]
#  ['Brother Minister: The Assassination of Malcolm X (1994)' 'Documentary']
#  ['Search for One-eye Jimmy, The (1996)' 'Comedy']
#  ['Celluloid Closet, The (1995)' 'Documentary']
#  ['Misérables, Les (1998)' 'Drama']
#  ['Love and Basketball (2000)' 'Drama|Romance']
#  ['Prince of the City (1981)' 'Drama']
#  ['Mary Poppins (1964)' "Children's|Comedy|Musical"]
#  ["Billy's Holiday (1995)" 'Drama']
#  ["Jumpin' Jack Flash (1986)" 'Action|Comedy|Romance|Thriller']
#  ["McHale's Navy (1997)" 'Comedy|War']
#  ['Multiplicity (1996)' 'Comedy']
#  ['Sword in the Stone, The (1963)' "Animation|Children's"]]
# GOT IT!!!!
#
# recommended items ids : [3276 3466 3000 2098 1588 3017  481   45 2782 2646  948  352 2378 3583
#  1632  113 2324  944  267 1135]
# recommened items :
#  [['Gun Shy (2000)' 'Comedy']
#  ['Heart and Souls (1993)' 'Comedy|Fantasy']
#  ['Princess Mononoke, The (Mononoke Hime) (1997)'
#   'Action|Adventure|Animation']
#  ['Son of Flubber (1963)' "Children's|Comedy"]
#  ['George of the Jungle (1997)' "Children's|Comedy"]
#  ['Creepshow 2 (1987)' 'Horror']
#  ['Kalifornia (1993)' 'Drama|Thriller']
#  ['To Die For (1995)' 'Comedy|Drama']
#  ['Pit and the Pendulum (1961)' 'Horror']
#  ['House of Dracula (1945)' 'Horror']
#  ['Giant (1956)' 'Drama']
#  ['Crooklyn (1994)' 'Comedy']
#  ['Police Academy (1984)' 'Comedy']
#  ['Black Tights (Les Collants Noirs) (1960)' 'Drama']
#  ['Smile Like Yours, A (1997)' 'Comedy|Romance']
#  ['Before and After (1996)' 'Drama|Mystery']
#  ['Life Is Beautiful (La Vita è bella) (1997)' 'Comedy|Drama']
#  ['Lost Horizon (1937)' 'Drama']
#  ['Major Payne (1994)' 'Comedy']
#  ['Private Benjamin (1980)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [1401   89   72 1450 2033 1673 2944 2440 2604 1670  570 1863  709 3858
#   899 1059  217 1521 2853  245]
# recommened items :
#  [list(['Ghosts of Mississippi (1996)', 'Drama'])
#  list(['Nick of Time (1995)', 'Action|Thriller'])
#  list(['Kicking and Screaming (1995)', 'Comedy|Drama'])
#  list(['Prisoner of the Mountains (Kavkazsky Plennik) (1996)', 'War'])
#  list(['Black Cauldron, The (1985)', "Animation|Children's"])
#  list(['Boogie Nights (1997)', 'Drama'])
#  list(['Dirty Dozen, The (1967)', 'Action|War'])
#  list(['Another Day in Paradise (1998)', 'Drama'])
#  list(['Let it Come Down: The Life of Paul Bowles (1998)', 'Documentary'])
#  list(['Welcome To Sarajevo (1997)', 'Drama|War'])
#  list(['Slingshot, The (Kådisbellan ) (1993)', 'Comedy|Drama'])
#  list(['Major League: Back to the Minors (1998)', 'Comedy'])
#  list(['Oliver & Company (1988)', "Animation|Children's"])
#  list(['Cecil B. Demented (2000)', 'Comedy'])
#  list(["Singin' in the Rain (1952)", 'Musical|Romance'])
#  list(["William Shakespeare's Romeo and Juliet (1996)", 'Drama|Romance'])
#  list(['Babysitter, The (1995)', 'Drama|Thriller']) list(['Not in list'])
#  list(['Communion (a.k.a. Alice, Sweet Alice/Holy Terror) (1977)', 'Horror'])
#  list(['Glass Shield, The (1994)', 'Crime|Drama'])]
# GOT IT!!!!
#
# recommended items ids : [ 243  192 3093  311 2110 1796 3407 2165 3741 2613 3281 3073 2398 1342
#  1539  281 1314 1669   17 3244]
# recommened items :
#  [['Gordy (1995)' 'Comedy']
#  ['Show, The (1995)' 'Documentary']
#  ['McCabe & Mrs. Miller (1971)' 'Drama|Western']
#  ['Relative Fear (1994)' 'Horror|Thriller']
#  ["Dead Men Don't Wear Plaid (1982)" 'Comedy|Crime|Thriller']
#  ["In God's Hands (1998)" 'Action|Drama']
#  ['Carriers Are Waiting, The (Les Convoyeurs Attendent) (1999)'
#   'Comedy|Drama']
#  ['Your Friends and Neighbors (1998)' 'Drama']
#  ['Badlands (1973)' 'Crime|Drama']
#  ['Night of the Comet (1984)' 'Action|Horror|Sci-Fi']
#  ['Brandon Teena Story, The (1998)' 'Documentary']
#  ['Sandpiper, The (1965)' 'Drama|Romance']
#  ['Miracle on 34th Street (1947)' 'Drama']
#  ['Candyman (1992)' 'Horror']
#  ['Twin Town (1997)' 'Comedy|Crime']
#  ["Nobody's Fool (1994)" 'Drama']
#  ['Breathing Room (1996)' 'Romance']
#  ['Tango Lesson, The (1997)' 'Romance']
#  ['Sense and Sensibility (1995)' 'Drama|Romance']
#  ['Goodbye Girl, The (1977)' 'Comedy|Romance']]
# GOT IT!!!!
#
# recommended items ids : [1118 2610 3343  263  304 3059  713 1191 1080 2627  399 3637 2294 1351
#  1127 3840 2356 2926 1219 1245]
# recommened items :
#  [['Tashunga (1995)' 'Adventure|Western']
#  ['Three Seasons (1999)' 'Drama']
#  ['And God Created Woman (1988)' 'Comedy|Drama|Romance']
#  ['Ladybird Ladybird (1994)' 'Drama']
#  ['Roommates (1995)' 'Comedy|Drama']
#  ['British Intelligence (1940)' 'Drama']
#  ['Of Love and Shadows (1994)' 'Drama']
#  ['Madonna: Truth or Dare (1991)' 'Documentary']
#  ["Monty Python's Life of Brian (1979)" 'Comedy']
#  ['Endurance (1998)' 'Documentary|Drama']
#  ['Girl in the Cadillac (1995)' 'Drama']
#  ['Vagabond (Sans toit ni loi) (1985)' 'Drama']
#  ['Antz (1998)' "Animation|Children's"]
#  ['Blood & Wine (1997)' 'Drama']
#  ['Abyss, The (1989)' 'Action|Adventure|Sci-Fi|Thriller']
#  ['Pumpkinhead (1988)' 'Horror']
#  ['Celebrity (1998)' 'Comedy']
#  ['Hairspray (1988)' 'Comedy|Drama']
#  ['Psycho (1960)' 'Horror|Thriller']
#  ["Miller's Crossing (1990)" 'Drama']]
# GOT IT!!!!
#
# recommended items ids : [ 853 3177  129 3519  401 1595 2507 3113 1652 1949  664 2216 3015 1811
#  1089  932  727 3350 3053  663]
# recommened items :
#  [['Dingo (1992)' 'Drama']
#  ['Next Friday (1999)' 'Comedy']
#  ['Pie in the Sky (1995)' 'Comedy|Romance']
#  ['Force 10 from Navarone (1978)' 'Action|War']
#  ['Mirage (1995)' 'Action|Thriller']
#  ['Free Willy 3: The Rescue (1997)' "Adventure|Children's|Drama"]
#  ['Breakfast of Champions (1999)' 'Comedy']
#  ['End of Days (1999)' 'Action|Thriller']
#  ['Year of the Horse (1997)' 'Documentary']
#  ['Man for All Seasons, A (1966)' 'Drama']
#  ['Faithful (1996)' 'Comedy']
#  ['Skin Game, The (1931)' 'Drama']
#  ['Coma (1978)' 'Thriller']
#  ['Niagara, Niagara (1997)' 'Drama']
#  ['Reservoir Dogs (1992)' 'Crime|Thriller']
#  ['Affair to Remember, An (1957)' 'Romance']
#  ['War Stories (1995)' 'Documentary']
#  ['Raisin in the Sun, A (1961)' 'Drama']
#  ['Messenger: The Story of Joan of Arc, The (1999)' 'Drama|War']
#  ['Kids in the Hall: Brain Candy (1996)' 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [2564  887 3889 1596  808 1930 1999 2701 3434   36  869 3602  489 2924
#  3087 2948 1682 3036 3532 3608]
# recommened items :
#  [['Empty Mirror, The (1999)' 'Drama']
#  ['Talk of Angels (1998)' 'Drama']
#  ['Highlander: Endgame (2000)' 'Action|Adventure|Fantasy']
#  ['Career Girls (1997)' 'Drama']
#  ['Alaska (1996)' "Adventure|Children's"]
#  ['Cavalcade (1933)' 'Drama']
#  ['Exorcist III, The (1990)' 'Horror']
#  ['Wild Wild West (1999)' 'Action|Sci-Fi|Western']
#  ['Death Wish V: The Face of Death (1994)' 'Action|Drama']
#  ['Dead Man Walking (1995)' 'Drama']
#  ['Kansas City (1996)' 'Crime']
#  ['G. I. Blues (1960)' 'Musical']
#  ['Made in America (1993)' 'Comedy']
#  ['Drunken Master (Zui quan) (1979)' 'Action|Comedy']
#  ['Scrooged (1988)' 'Comedy']
#  ['From Russia with Love (1963)' 'Action']
#  ['Truman Show, The (1998)' 'Drama']
#  ['Quest for Fire (1981)' 'Adventure']
#  ['Freedom for Us (À nous la liberté ) (1931)' 'Comedy']
#  ["Pee-wee's Big Adventure (1985)" 'Comedy']]
# GOT IT!!!!
#
# recommended items ids : [2567 3494 3403 3529  434 3599 2136 1070 2855 3845  994 2170 3856 1167
#  3687 2408 1992 3812  703 3441]
# recommened items :
#  [['EDtv (1999)' 'Comedy']
#  ['True Grit (1969)' 'Adventure|Western']
#  ['Raise the Titanic (1980)' 'Drama|Thriller']
#  ['Postman Always Rings Twice, The (1981)' 'Crime|Thriller']
#  ['Cliffhanger (1993)' 'Action|Adventure|Crime']
#  ['Anchors Aweigh (1945)' 'Comedy|Musical']
#  ['Nutty Professor, The (1963)' 'Comedy']
#  ['Macao (1952)' 'Adventure']
#  ['Nightmares (1983)' 'Horror']
#  ['And God Created Woman (Et Dieu&#8230;Créa la Femme) (1956)' 'Drama']
#  ['Big Night (1996)' 'Drama']
#  ['Wrongfully Accused (1998)' 'Action|Comedy']
#  ['Autumn Heart (1999)' 'Drama']
#  ['Dear God (1996)' 'Comedy']
#  ['Light Years (1988)' 'Sci-Fi']
#  ['Cocoon: The Return (1988)' 'Comedy|Sci-Fi']
#  ["Child's Play 2 (1990)" 'Horror']
#  ['Everything You Always Wanted to Know About Sex (1972)' 'Comedy']
#  ['Boys (1996)' 'Drama']
#  ['Red Dawn (1984)' 'Action|War']]
# GOT IT!!!!
#
# recommended items ids : [3633 2775 1426 2527 2458 2255 2577  824 3570  778 1092 3033 2814 2013
#  1131 3609  957 3049 3145  857]
# recommened items :
#  [["On Her Majesty's Secret Service (1969)" 'Action']
#  ['Head On (1998)' 'Drama']
#  ['Zeus and Roxanne (1997)' "Children's"]
#  ['Westworld (1973)' 'Action|Sci-Fi|Thriller|Western']
#  ['Armed and Dangerous (1986)' 'Comedy|Crime']
#  ['Young Doctors in Love (1982)' 'Comedy']
#  ['Metroland (1997)' 'Comedy|Drama']
#  ['Kaspar Hauser (1993)' 'Drama']
#  ['Last September, The (1999)' 'Drama']
#  ['Trainspotting (1996)' 'Drama']
#  ['Basic Instinct (1992)' 'Mystery|Thriller']
#  ['Spaceballs (1987)' 'Comedy|Sci-Fi']
#  ['Bat, The (1959)' 'Horror']
#  ['Poseidon Adventure, The (1972)' 'Action|Adventure']
#  ['Jean de Florette (1986)' 'Drama']
#  ['Regret to Inform (1998)' 'Documentary']
#  ['Scarlet Letter, The (1926)' 'Drama']
#  ['How I Won the War (1967)' 'Comedy|War']
#  ['Cradle Will Rock, The (1999)' 'Drama']
#  ['Crows and Sparrows (1949)' 'Drama']]
# GOT IT!!!!
#
# recommended items ids : [3109 2239 2384 2504 3743 1524 3121 2718  422 2556  954    7 2611 3294
#  2386 2117 1609 3915 3823   97]
# recommened items :
#  [['River, The (1984)' 'Drama']
#  ["Swept Away (Travolti da un insolito destino nell'azzurro mare d'Agosto) (1975)"
#   'Comedy|Drama']
#  ['Babe: Pig in the City (1998)' "Children's|Comedy"]
#  ['200 Cigarettes (1999)' 'Comedy|Drama']
#  ['Boys and Girls (2000)' 'Comedy|Romance']
#  ['Turning, The (1992)' 'Drama']
#  ['Hitch-Hiker, The (1953)' 'Film-Noir']
#  ['Drop Dead Gorgeous (1999)' 'Comedy']
#  ['Blink (1994)' 'Thriller']
#  ['Telling You (1998)' 'Comedy|Drama|Romance']
#  ['Mr. Smith Goes to Washington (1939)' 'Drama']
#  ['Sabrina (1995)' 'Comedy|Romance']
#  ['Winslow Boy, The (1998)' 'Drama']
#  ['Eaten Alive (1976)' 'Horror']
#  ['Jerry Springer: Ringmaster (1998)' 'Drama']
#  ['Nineteen Eighty-Four (1984)' 'Drama|Sci-Fi']
#  ['187 (1997)' 'Drama']
#  ['Girlfight (2000)' 'Drama']
#  ['Wonderland (1999)' 'Drama']
#  ['Hate (Haine, La) (1995)' 'Drama']]
#
# precision : 0.8421052631578947, episode_reward : 22
